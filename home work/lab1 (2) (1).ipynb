# %% [markdown]
# ## Задача классификации Мобильных игр

# %% [markdown]
# # Задача
# Имеем датасет с более, чем с 17000 мобильных игр.
# Задача: имея различную информцию об игре, отнести ее к определенному возрастному классу: 4+, 9+, 12+ или 17+

# %% [markdown]
# ## 1. Загружаем данные

# %%
import pandas as pd

# %%
from numba import njit
from numba import jit

# %%
import numpy as np            
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns          
import sklearn

# %%
from sklearn.metrics import r2_score, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from datetime import datetime

# %%
url = "https://raw.githubusercontent.com/ErmachenkoBoris/machineLearning/master/datasets/appstore_games.csv"
data_raw = pd.read_csv(url)

# %%
data_raw.shape
# Out:
# (17007, 18)

# %%
data_raw.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# 0                  4.0             3553.0   2.99              NaN
# 1                  3.5              284.0   1.99              NaN
# 2                  3.0             8376.0   0.00              NaN
# 3                  3.5           190394.0   0.00              NaN
# 4                  3.5               28.0   2.99              NaN
#
#                                          Description  \
# 0  Join over 21,000,000 of our fans and download ...
# 1  The classic game of Reversi, also known as Oth...
# 2  Play the classic strategy game Othello (also k...
# 3  Top 100 free app for over a year.\nRated "Best...
# 4  "Senet Deluxe - The Ancient Game of Life and A...
#
#                   Developer Age Rating  \
# 0  Mighty Mighty Good Games         4+
# 1          Kiss The Machine         4+
# 2               Bayou Games         4+
# 3  Mighty Mighty Good Games         4+
# 4           RoGame Software         4+
#
#                                            Languages        Size  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 1                                                 EN  12328960.0
# 2                                                 EN    674816.0
# 3  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  21552128.0
# 4  DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...  34689024.0
#
#   Primary Genre                             Genres Original Release Date  \
# 0         Games            Games, Strategy, Puzzle            11/07/2008
# 1         Games             Games, Strategy, Board            11/07/2008
# 2         Games             Games, Board, Strategy            11/07/2008
# 3         Games            Games, Strategy, Puzzle            23/07/2008
# 4         Games  Games, Strategy, Board, Education            18/07/2008
#
#   Current Version Release Date
# 0                   30/05/2017
# 1                   17/05/2018
# 2                    5/09/2017
# 3                   30/05/2017
# 4                   22/07/2018

# %%
data_raw.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %% [markdown]
# Мы видим, что мы имеем следующие столбцы и признаки:
#
# - `URL` - url на игру
# - `ID` - id игры
# - `Name` - имя игры
# - `Subtitle` - подзаголовок,
# - `Icon URL` - url на иконку,
# - `Average User Rating` - числовой признак, рейтинг игры,
# - `User Rating Count` - числовой признак, количество оценок,
# - `Price` - числовой признак, цена,
# - `In-app Purchases` - бинарный признак, покупки внутри приложения,
# - `Description` - описание, номинальный признак,
# - `Developer` - разработчик, категориальный признак,
# - `Age Rating` - возрастное ограничение, номинальный(категориальный признак),
# - `Languages` - номинальный признак, языки,
# - `Size` - размер приложения, количественный признак,
# - `Primary Genre` - основной жанр, номинальный признак,
# - `Genres` -поджанр, номинальный признак,
# - `Original Release Date` - дата первого релиза, номинальный признак
# - `Current Version Release Date` - дата последнего релиза, номинальный признак
#
#
# Требуется отнести игру к одному из возрастному ограничению, имея всю остальную информацию об игре

# %% [markdown]
# Столбцы `'Age Rating'`, `'Primary Genre'`, `'Developer'` содержат категориальное значение

# %%
data_raw['Age Rating'] = data_raw['Age Rating'].astype('category')

# %%
data_raw['Primary Genre'] = data_raw['Primary Genre'].astype('category')

# %%
data_raw['Developer'] = data_raw['Developer'].astype('category')

# %%
data_raw['Age Rating'].dtype
# Out:
# CategoricalDtype(categories=['12+', '17+', '4+', '9+'], ordered=False)

# %%
data_raw['Primary Genre'].dtype
# Out:
# CategoricalDtype(categories=['Book', 'Business', 'Education', 'Entertainment', 'Finance',
#                   'Food & Drink', 'Games', 'Health & Fitness', 'Lifestyle',
#                   'Medical', 'Music', 'Navigation', 'News', 'Productivity',
#                   'Reference', 'Shopping', 'Social Networking', 'Sports',
#                   'Stickers', 'Travel', 'Utilities'],
#                  ordered=False)

# %%
data_raw['Developer'].dtype
# Out:
# CategoricalDtype(categories=['"Alex Artem'ev"', '"ByteRockers' Games GmbH & Co. KG"',
#                   '"Daniel O'Sullivan"', '"Don't Blink Studios"',
#                   '"Ellie's Games, LLC"', '"Galen O'Shea"',
#                   '"Igor's Software Labs LLC"', '"It's All A Game LLC"',
#                   '"Joe o'donovan"', '"Joe's Apps"',
#                   ...
#                   'zhiguo lin', 'zhijuan zhang', 'zhili zhao', 'zhixiang zhao',
#                   'zhong chen', 'zhou zhimeng',
#                   'zinWorks Studios (zinCode, LLC)', 'zomido med',
#                   'zuiyouqu youxi', 'zurab inaishvili'],
#                  ordered=False)

# %% [markdown]
# ### Преобразование столбцов

# %%
data_raw.loc[:, 'Genres']
# Out:
# 0                       Games, Strategy, Puzzle
# 1                        Games, Strategy, Board
# 2                        Games, Board, Strategy
# 3                       Games, Strategy, Puzzle
# 4             Games, Strategy, Board, Education
#                           ...
# 17002    Games, Entertainment, Casual, Strategy
# 17003                   Games, Family, Strategy
# 17004                           Games, Strategy
# 17005                   Games, Strategy, Action
# 17006                   Games, Strategy, Puzzle
# Name: Genres, Length: 17007, dtype: object

# %% [markdown]
# Заметим, что значение `'Genres'` содержит несколько жанров
# Для того, чтобы анализировать этот признак, лучше создать для каждого столбец со значениями:
# 0 - если данный жанр не присутсвует в игре,
# 1 - если жанр присутсвует в данной игре
# (бинарный признак)
# Для этого необходимо сначала узнать, как жанры вообще есть

# %%
# поиск жанров

genres_array = []
for index, row in data_raw.iterrows():
    genres_row = row['Genres'].split(', ');
    if len(genres_array) == 0 and len(genres_row)>0:
        genres_array = genres_row[:];
    elif len(genres_row)>0:
         genres_array.extend(genres_row);
uniq = list(dict.fromkeys(genres_array))

# %% [markdown]
# получили массив с уникальными значениями жанров:

# %%
print(uniq)
# Out:
# ['Games', 'Strategy', 'Puzzle', 'Board', 'Education', 'Entertainment', 'Casual', 'Action', 'Card', 'Simulation', 'Finance', 'Word', 'Role Playing', 'Sports', 'Adventure', 'Family', 'Travel', 'Casino', 'Business', 'Navigation', 'Reference', 'Lifestyle', 'Social Networking', 'Medical', 'Utilities', 'Trivia', 'Racing', 'Books', 'Music', 'Productivity', 'Health & Fitness', 'Food & Drink', 'News', 'Photo & Video', 'Stickers', 'Emoji & Expressions', 'Sports & Activities', 'Gaming', 'Comics & Cartoons', 'Animals & Nature', 'People', 'Shopping', 'Kids & Family', 'Art', 'Places & Objects', 'Weather', 'Magazines & Newspapers']

# %% [markdown]
# отсортируем его:

# %%
uniq.sort()
print(uniq)
# Out:
# ['Action', 'Adventure', 'Animals & Nature', 'Art', 'Board', 'Books', 'Business', 'Card', 'Casino', 'Casual', 'Comics & Cartoons', 'Education', 'Emoji & Expressions', 'Entertainment', 'Family', 'Finance', 'Food & Drink', 'Games', 'Gaming', 'Health & Fitness', 'Kids & Family', 'Lifestyle', 'Magazines & Newspapers', 'Medical', 'Music', 'Navigation', 'News', 'People', 'Photo & Video', 'Places & Objects', 'Productivity', 'Puzzle', 'Racing', 'Reference', 'Role Playing', 'Shopping', 'Simulation', 'Social Networking', 'Sports', 'Sports & Activities', 'Stickers', 'Strategy', 'Travel', 'Trivia', 'Utilities', 'Weather', 'Word']

# %% [markdown]
# Теперь, когда мы узнали список признаков, добавим их в нашу таблицу:

# %%
for genre in uniq:
    data_raw[genre] = 0

# %%
data_raw.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date',
#        'Action', 'Adventure', 'Animals & Nature', 'Art', 'Board', 'Books',
#        'Business', 'Card', 'Casino', 'Casual', 'Comics & Cartoons',
#        'Education', 'Emoji & Expressions', 'Entertainment', 'Family',
#        'Finance', 'Food & Drink', 'Games', 'Gaming', 'Health & Fitness',
#        'Kids & Family', 'Lifestyle', 'Magazines & Newspapers', 'Medical',
#        'Music', 'Navigation', 'News', 'People', 'Photo & Video',
#        'Places & Objects', 'Productivity', 'Puzzle', 'Racing', 'Reference',
#        'Role Playing', 'Shopping', 'Simulation', 'Social Networking', 'Sports',
#        'Sports & Activities', 'Stickers', 'Strategy', 'Travel', 'Trivia',
#        'Utilities', 'Weather', 'Word'],
#       dtype='object')

# %% [markdown]
# присвоим значение 1, если данный тип пристутсвует в жанрах игры

# %%
for index, row in data_raw.iterrows():
    for genre in uniq:
        if row['Genres'].find(genre) >= 0:
            data_raw.loc[index, genre] = 1

# %% [markdown]
# Проделаем тоже самое для столбца с языками, так как он тоже содержит набор различных параметров

# %%
data_raw['Languages'].dtype
# Out:
# dtype('O')

# %%
import math

# %%
# поиск языков
# если значение пропущено, то будем считать, что игра на английском языке
len_array = []
for index, row in data_raw.iterrows():
    if not row['Languages'] is np.nan:
      len_row = row['Languages'].split(', ');
      if len(len_array) == 0 and len(len_row)>0:
          len_array = len_row[:];
      elif len(len_row)>0:
                  len_array.extend(len_row);
    else:
       data_raw.loc[index, 'Languages'] = 'EN'
uniq = list(dict.fromkeys(len_array))

# %%
uniq.sort()
print(uniq)
# Out:
# ['AF', 'AM', 'AR', 'AS', 'AY', 'AZ', 'BE', 'BG', 'BN', 'BO', 'BR', 'BS', 'CA', 'CS', 'CY', 'DA', 'DE', 'DZ', 'EL', 'EN', 'EO', 'ES', 'ET', 'EU', 'FA', 'FI', 'FO', 'FR', 'GA', 'GD', 'GL', 'GN', 'GU', 'GV', 'HE', 'HI', 'HR', 'HU', 'HY', 'ID', 'IS', 'IT', 'IU', 'JA', 'JV', 'KA', 'KK', 'KL', 'KM', 'KN', 'KO', 'KR', 'KS', 'KU', 'KY', 'LA', 'LO', 'LT', 'LV', 'MG', 'MI', 'MK', 'ML', 'MN', 'MR', 'MS', 'MT', 'MY', 'NB', 'NE', 'NL', 'NN', 'NO', 'OM', 'OR', 'PA', 'PL', 'PS', 'PT', 'QU', 'RN', 'RO', 'RU', 'RW', 'SA', 'SD', 'SE', 'SI', 'SK', 'SL', 'SO', 'SQ', 'SR', 'SU', 'SV', 'SW', 'TA', 'TE', 'TG', 'TH', 'TI', 'TK', 'TL', 'TO', 'TR', 'TT', 'UG', 'UK', 'UR', 'UZ', 'VI', 'XH', 'YI', 'ZH', 'ZU']

# %%
#добавляем новые столбцы и заполняем нулями
for lang in uniq:
    data_raw[lang] = 0

# %%
#если игра содержит данный язык ставим 1 в соотвествующий столбец
for index, row in data_raw.iterrows():
    for lan in uniq:
        if row['Languages'].find(lan) >= 0:
            data_raw.loc[index, lan] = 1

# %%
data_raw.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        ...
#        'TT', 'UG', 'UK', 'UR', 'UZ', 'VI', 'XH', 'YI', 'ZH', 'ZU'],
#       dtype='object', length=179)

# %% [markdown]
# ## Преобразование столбцов с датой

# %%
# приводим строки с датой к дате
import datetime as DT


for index, row in data_raw.iterrows():
    data_raw.loc[index, 'Original Release Date'] = DT.datetime.strptime(row['Original Release Date'], '%d/%m/%Y').date()
    data_raw.loc[index, 'Current Version Release Date'] = DT.datetime.strptime(row['Current Version Release Date'], '%d/%m/%Y').date()

# %%
# преобразуем даты в числовое значение


for index, row in data_raw.iterrows():
  date1 = row['Original Release Date']
  date2 = row['Current Version Release Date']
  data_raw.loc[index, 'Original Release Date'] = (DT.datetime.now() - datetime(date1.year, date1.month, date1.day)).total_seconds()
  data_raw.loc[index, 'Current Version Release Date'] = (DT.datetime.now() - datetime(date2.year, date2.month, date2.day)).total_seconds()

# %%
# проверка
data_raw.loc[:10, 'Original Release Date']
# Out:
# 0     3.92256e+08
# 1     3.92256e+08
# 2     3.92256e+08
# 3     3.91219e+08
# 4     3.91651e+08
# 5     3.90614e+08
# 6     3.90614e+08
# 7     3.90268e+08
# 8     3.90268e+08
# 9     3.90441e+08
# 10    3.89577e+08
# Name: Original Release Date, dtype: object

# %%
data_raw.loc[:10, 'Current Version Release Date']
# Out:
# 0     1.11888e+08
# 1     8.14747e+07
# 2      1.0342e+08
# 3     1.11888e+08
# 4     7.57723e+07
# 5     5.14939e+07
# 6     2.23603e+08
# 7     6.94651e+07
# 8     9.65947e+07
# 9     3.90441e+08
# 10    3.85257e+08
# Name: Current Version Release Date, dtype: object

# %% [markdown]
# ### Удаление ненужных столбцов
# после преобразований столбцы '`Genres`' и '`Languages`' больше не нужны, удалим их

# %%
data_raw.drop(['Genres', 'Languages'], axis='columns', inplace=True)
data_raw.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        ...
#        'TT', 'UG', 'UK', 'UR', 'UZ', 'VI', 'XH', 'YI', 'ZH', 'ZU'],
#       dtype='object', length=177)

# %% [markdown]
# Кроме того, очевидно, что столбцы, содержащие URL никак нам не помогут решить поставленную задачу. Удалим их тоже

# %%
data_raw.drop(['URL', 'Icon URL'], axis='columns', inplace=True)

# %% [markdown]
# Также столбцы с индексом, именем и описание и подзаголовком тоже нам не помогут

# %%
data_raw.drop(['ID', 'Name', 'Subtitle', 'Description'], axis='columns', inplace=True)

# %%
data_raw.columns
# Out:
# Index(['Average User Rating', 'User Rating Count', 'Price', 'In-app Purchases',
#        'Developer', 'Age Rating', 'Size', 'Primary Genre',
#        'Original Release Date', 'Current Version Release Date',
#        ...
#        'TT', 'UG', 'UK', 'UR', 'UZ', 'VI', 'XH', 'YI', 'ZH', 'ZU'],
#       dtype='object', length=171)

# %% [markdown]
# ## Заполнение пропущенных значений

# %%
pd.options.display.max_rows = 200
data_raw.isna().sum()
# Out:
# Average User Rating             9446
# User Rating Count               9446
# Price                             24
# In-app Purchases                9324
# Developer                          0
# Age Rating                         0
# Size                               1
# Primary Genre                      0
# Original Release Date              0
# Current Version Release Date       0
# Action                             0
# Adventure                          0
# Animals & Nature                   0
# Art                                0
# Board                              0
# Books                              0
# Business                           0
# Card                               0
# Casino                             0
# Casual                             0
# Comics & Cartoons                  0
# Education                          0
# Emoji & Expressions                0
# Entertainment                      0
# Family                             0
# Finance                            0
# Food & Drink                       0
# Games                              0
# Gaming                             0
# Health & Fitness                   0
# Kids & Family                      0
# Lifestyle                          0
# Magazines & Newspapers             0
# Medical                            0
# Music                              0
# Navigation                         0
# News                               0
# People                             0
# Photo & Video                      0
# Places & Objects                   0
# Productivity                       0
# Puzzle                             0
# Racing                             0
# Reference                          0
# Role Playing                       0
# Shopping                           0
# Simulation                         0
# Social Networking                  0
# Sports                             0
# Sports & Activities                0
# Stickers                           0
# Strategy                           0
# Travel                             0
# Trivia                             0
# Utilities                          0
# Weather                            0
# Word                               0
# AF                                 0
# AM                                 0
# AR                                 0
# AS                                 0
# AY                                 0
# AZ                                 0
# BE                                 0
# BG                                 0
# BN                                 0
# BO                                 0
# BR                                 0
# BS                                 0
# CA                                 0
# CS                                 0
# CY                                 0
# DA                                 0
# DE                                 0
# DZ                                 0
# EL                                 0
# EN                                 0
# EO                                 0
# ES                                 0
# ET                                 0
# EU                                 0
# FA                                 0
# FI                                 0
# FO                                 0
# FR                                 0
# GA                                 0
# GD                                 0
# GL                                 0
# GN                                 0
# GU                                 0
# GV                                 0
# HE                                 0
# HI                                 0
# HR                                 0
# HU                                 0
# HY                                 0
# IS                                 0
# IT                                 0
# IU                                 0
# JA                                 0
# JV                                 0
# KA                                 0
# KK                                 0
# KL                                 0
# KM                                 0
# KN                                 0
# KO                                 0
# KR                                 0
# KS                                 0
# KU                                 0
# KY                                 0
# LA                                 0
# LO                                 0
# LT                                 0
# LV                                 0
# MG                                 0
# MI                                 0
# MK                                 0
# ML                                 0
# MN                                 0
# MR                                 0
# MS                                 0
# MT                                 0
# MY                                 0
# NB                                 0
# NE                                 0
# NL                                 0
# NN                                 0
# NO                                 0
# OM                                 0
# OR                                 0
# PA                                 0
# PL                                 0
# PS                                 0
# PT                                 0
# QU                                 0
# RN                                 0
# RO                                 0
# RU                                 0
# RW                                 0
# SA                                 0
# SD                                 0
# SE                                 0
# SI                                 0
# SK                                 0
# SL                                 0
# SO                                 0
# SQ                                 0
# SR                                 0
# SU                                 0
# SV                                 0
# SW                                 0
# TA                                 0
# TE                                 0
# TG                                 0
# TH                                 0
# TI                                 0
# TK                                 0
# TL                                 0
# TO                                 0
# TR                                 0
# TT                                 0
# UG                                 0
# UK                                 0
# UR                                 0
# UZ                                 0
# VI                                 0
# XH                                 0
# YI                                 0
# ZH                                 0
# ZU                                 0
# dtype: int64

# %%
data_raw.loc[:18, 'In-app Purchases']
# Out:
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                         1.99
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                        0.99
# 16                                        0.99
# 17                                         NaN
# 18    1.99, 0.99, 1.99, 0.99, 4.99, 1.99, 1.99
# Name: In-app Purchases, dtype: object

# %% [markdown]
# Так как цены есть числовая характеристика, то преобразовывать этот столбец в различные признаки (как с language и genre) смысла нет.
# Вместо этого будем считать, что если информация об этом признаке не указана - то внутренних покупок нет, а если есть, то они есть. Таким образом, превратим этот признак в бинарный

# %%
for index, row in data_raw.iterrows():
  if row['In-app Purchases'] is np.nan:
    data_raw.loc[index, 'In-app Purchases'] = 0
  else:
    data_raw.loc[index, 'In-app Purchases'] = 1

# %% [markdown]
# Заполним медианами пропущенные значения в столбцах, соответствующих числовым признакам:

# %%
data_raw.fillna(data_raw.median(axis = 0), axis=0 , inplace=True)

# %%
data_raw.isna().sum()
# Out:
# Average User Rating             0
# User Rating Count               0
# Price                           0
# In-app Purchases                0
# Developer                       0
# Age Rating                      0
# Size                            0
# Primary Genre                   0
# Original Release Date           0
# Current Version Release Date    0
# Action                          0
# Adventure                       0
# Animals & Nature                0
# Art                             0
# Board                           0
# Books                           0
# Business                        0
# Card                            0
# Casino                          0
# Casual                          0
# Comics & Cartoons               0
# Education                       0
# Emoji & Expressions             0
# Entertainment                   0
# Family                          0
# Finance                         0
# Food & Drink                    0
# Games                           0
# Gaming                          0
# Health & Fitness                0
# Kids & Family                   0
# Lifestyle                       0
# Magazines & Newspapers          0
# Medical                         0
# Music                           0
# Navigation                      0
# News                            0
# People                          0
# Photo & Video                   0
# Places & Objects                0
# Productivity                    0
# Puzzle                          0
# Racing                          0
# Reference                       0
# Role Playing                    0
# Shopping                        0
# Simulation                      0
# Social Networking               0
# Sports                          0
# Sports & Activities             0
# Stickers                        0
# Strategy                        0
# Travel                          0
# Trivia                          0
# Utilities                       0
# Weather                         0
# Word                            0
# AF                              0
# AM                              0
# AR                              0
# AS                              0
# AY                              0
# AZ                              0
# BE                              0
# BG                              0
# BN                              0
# BO                              0
# BR                              0
# BS                              0
# CA                              0
# CS                              0
# CY                              0
# DA                              0
# DE                              0
# DZ                              0
# EL                              0
# EN                              0
# EO                              0
# ES                              0
# ET                              0
# EU                              0
# FA                              0
# FI                              0
# FO                              0
# FR                              0
# GA                              0
# GD                              0
# GL                              0
# GN                              0
# GU                              0
# GV                              0
# HE                              0
# HI                              0
# HR                              0
# HU                              0
# HY                              0
# IS                              0
# IT                              0
# IU                              0
# JA                              0
# JV                              0
# KA                              0
# KK                              0
# KL                              0
# KM                              0
# KN                              0
# KO                              0
# KR                              0
# KS                              0
# KU                              0
# KY                              0
# LA                              0
# LO                              0
# LT                              0
# LV                              0
# MG                              0
# MI                              0
# MK                              0
# ML                              0
# MN                              0
# MR                              0
# MS                              0
# MT                              0
# MY                              0
# NB                              0
# NE                              0
# NL                              0
# NN                              0
# NO                              0
# OM                              0
# OR                              0
# PA                              0
# PL                              0
# PS                              0
# PT                              0
# QU                              0
# RN                              0
# RO                              0
# RU                              0
# RW                              0
# SA                              0
# SD                              0
# SE                              0
# SI                              0
# SK                              0
# SL                              0
# SO                              0
# SQ                              0
# SR                              0
# SU                              0
# SV                              0
# SW                              0
# TA                              0
# TE                              0
# TG                              0
# TH                              0
# TI                              0
# TK                              0
# TL                              0
# TO                              0
# TR                              0
# TT                              0
# UG                              0
# UK                              0
# UR                              0
# UZ                              0
# VI                              0
# XH                              0
# YI                              0
# ZH                              0
# ZU                              0
# dtype: int64

# %% [markdown]
# Ура! мы избавили от нулевых значений

# %% [markdown]
# ## Боремся с выбросами
# От чего зависит возрастное ограничение для игры в первую очередь ?
# Ответ на этот вопрос не очевиден

# %% [markdown]
# Попробуем посмотреть разброс по цене и по рейтингу

# %%
plt.scatter(data_raw['Price'], data_raw['Age Rating'], alpha=0.01)

# %%
data_raw['Price'].quantile([0.005,.01,.05,.1,.5,.9,.95,.99,.995])
# Out:
# 0.005     0.00
# 0.010     0.00
# 0.050     0.00
# 0.100     0.00
# 0.500     0.00
# 0.900     0.99
# 0.950     2.99
# 0.990     9.99
# 0.995    11.99
# Name: Price, dtype: float64

# %% [markdown]
# Вывод: 99.5% игр стоят меньше, чем 11.99

# %% [markdown]
# Проделаем тоже самое для рейтинга

# %%
plt.scatter(x='Average User Rating', y='Age Rating', data = data_raw, alpha=0.01)

# %%
data_raw['Average User Rating'].quantile([0.005,.01,.05,.1,.5,.9,.95,.99,.995])
# Out:
# 0.005    2.0
# 0.010    2.0
# 0.050    3.0
# 0.100    3.5
# 0.500    4.5
# 0.900    4.5
# 0.950    5.0
# 0.990    5.0
# 0.995    5.0
# Name: Average User Rating, dtype: float64

# %% [markdown]
# Удалим значения, в которых '`Price`' выходит за пределы 0.995, а '`Average User Rating`' менее 0.005

# %%
rows_to_drop = data_raw[
     (data_raw['Price'] > data_raw['Price'].quantile(0.995)) | 
    (data_raw['Average User Rating']  < data_raw['Average User Rating' ].quantile(0.005))].index
data = data_raw.drop(rows_to_drop)
data.shape
# Out:
# (16877, 171)

# %% [markdown]
# ### Выбросы по датам

# %%
plt.scatter(x='Original Release Date', y='Age Rating', data=data_raw, alpha=0.01)

# %% [markdown]
# Делаем вывод по графику, что явных выбросов здесь нет

# %%
plt.scatter(x='Current Version Release Date', y='Age Rating', data=data_raw, alpha=0.01)

# %% [markdown]
# Аналогично, так как значения увеличивают/уменьшают плотность равномерно, выбросов нет

# %%
# проделаем для User Rating Count
plt.scatter(x='User Rating Count', y='Average User Rating', data=data_raw, alpha=0.1)

# %%
data_raw['User Rating Count'].quantile([0.005,.01,.05,.1,.5,.9,.95,.99,.995])
# Out:
# 0.005        5.00
# 0.010        5.00
# 0.050        7.00
# 0.100       11.00
# 0.500       46.00
# 0.900      407.00
# 0.950     1934.80
# 0.990    24680.68
# 0.995    48840.02
# Name: User Rating Count, dtype: float64

# %%
# удаляем выбросы
rows_to_drop = data_raw[
     (data_raw['User Rating Count'] > data_raw['User Rating Count'].quantile(0.995)) | 
    (data_raw['User Rating Count']  < data_raw['User Rating Count' ].quantile(0.005))].index
data = data_raw.drop(rows_to_drop)
data.shape
# Out:
# (16921, 171)

# %% [markdown]
# # Визуализация и описательная статистика

# %% [markdown]
# Сейчас мы имеем очень много признаков из-за добавления признаков для языков и жанров.
# Для визуализации оставим только изначальные

# %%
data_vis = data_raw.filter(['Average User Rating','User Rating Count','Price', 'In-app Purchases', 'Size', 'Original Release Date', 'Current Version Release Date', 'Primary Genre', 'Developer', 'Age Rating'], axis=1)

# %%
data_vis.describe()
# Out:
#        Average User Rating  User Rating Count         Price  In-app Purchases  \
# count         17007.000000       1.700700e+04  17007.000000      17007.000000
# mean              4.304786       1.495572e+03      0.812271          0.451755
# std               0.546465       2.826484e+04      7.830260          0.497682
# min               1.000000       5.000000e+00      0.000000          0.000000
# 25%               4.500000       4.600000e+01      0.000000          0.000000
# 50%               4.500000       4.600000e+01      0.000000          0.000000
# 75%               4.500000       4.600000e+01      0.000000          1.000000
# max               5.000000       3.032734e+06    179.990000          1.000000
#
#                Size  Original Release Date  Current Version Release Date
# count  1.700700e+04           1.700700e+04                  1.700700e+04
# mean   1.157030e+08           1.508722e+08                  1.147995e+08
# std    2.036422e+08           7.214122e+07                  5.753410e+07
# min    5.132800e+04           3.594197e+07                  3.594197e+07
# 25%    2.295040e+07           9.538516e+07                  6.540436e+07
# 50%    5.676895e+07           1.399676e+08                  1.071355e+08
# 75%    1.330130e+08           1.965596e+08                  1.471388e+08
# max    4.005591e+09           3.922555e+08                  3.904411e+08

# %% [markdown]
# Для каждого количественного признака приведены средние значения, стандартное отклонение, минимальное и макимальное значения, медиана и значения квартилей.

# %% [markdown]
# Для категориальных признаков:

# %%
data_vis.describe(include=['category'])
# Out:
#        Primary Genre                                   Developer Age Rating
# count          17007                                       17007      17007
# unique            21                                        8693          4
# top            Games  Tapps Tecnologia da Informa\xe7\xe3o Ltda.         4+
# freq           16286                                         123      11806

# %%
plt.scatter(x='Age Rating', y='Current Version Release Date', data=data_raw, alpha=0.01)

# %%
plt.scatter(x='Age Rating', y='Developer', data=data_raw, alpha=0.01)

# %%
random_subset = np.random.choice(np.arange(data.shape[0]), size=1000, replace=False)

# %% [markdown]
# Построим все возможные диаграммы рассеивания для каждой пары переменных:

# %%
sns.pairplot(data_vis.iloc[random_subset], hue='Age Rating', diag_kind='hist')
plt.legend()
pass

# %% [markdown]
# Построим различные гистограммы

# %%
sns.distplot(data_vis.iloc[random_subset]['Price'], bins=100)
plt.grid()
pass
# Out:
# C:\Users\cbkf1\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x='Average User Rating', y='Price', alpha=.05, data=data_vis)

# %%
sns.distplot(data_vis.iloc[random_subset]['Original Release Date'], bins=1000)

# %%
sns.boxplot(x='Age Rating', y='Price', data = data_raw)
pass

# %%
sns.boxplot(x='Age Rating', y='Size', data = data_raw)

# %%
sns.violinplot(x='Age Rating', y='Size', data = data_raw)

# %% [markdown]
# ### Вычисление корреляции

# %%
from sklearn.preprocessing import LabelEncoder
corr_data = data_raw.copy()

le = LabelEncoder()

corr_data['Developer'] = le.fit_transform(corr_data['Developer'])
corr_data['Age Rating'] = le.fit_transform(corr_data['Age Rating'])
corr_data['Primary Genre'] = le.fit_transform(corr_data['Primary Genre'])

# %%
corr_data['Developer']
# Out:
# 0        4801
# 1        3992
# 2         905
# 3        4801
# 4        6067
#          ...
# 17002    8018
# 17003    6789
# 17004    7494
# 17005    6987
# 17006    8441
# Name: Developer, Length: 17007, dtype: int32

# %%
corr_mat_full = corr_data.corr()
corr_mat_full
# Out:
#                               Average User Rating  User Rating Count  \
# Average User Rating                      1.000000           0.007339
# User Rating Count                        0.007339           1.000000
# Price                                    0.010916          -0.003868
# In-app Purchases                        -0.024902           0.043768
# Developer                                0.010897           0.011315
# Age Rating                               0.018507           0.007664
# Size                                    -0.015571           0.040466
# Primary Genre                           -0.013807           0.001677
# Original Release Date                   -0.289427           0.041243
# Current Version Release Date            -0.188967          -0.038443
# Action                                  -0.003242           0.044429
# Adventure                               -0.003883          -0.001264
# Animals & Nature                         0.005479          -0.000787
# Art                                      0.003874          -0.000556
# Board                                   -0.069857          -0.009009
# Books                                   -0.001326          -0.002036
# Business                                -0.006735          -0.002253
# Card                                    -0.018160          -0.001842
# Casino                                   0.008349          -0.001613
# Casual                                   0.062929          -0.009470
# Comics & Cartoons                        0.003874          -0.000556
# Education                                0.031447          -0.011016
# Emoji & Expressions                      0.008802          -0.001527
# Entertainment                           -0.039464           0.014812
# Family                                   0.020612          -0.005337
# Finance                                 -0.005007           0.005127
# Food & Drink                             0.005822          -0.002961
# Games                                         NaN                NaN
# Gaming                                   0.006685          -0.001972
# Health & Fitness                         0.009967           0.018400
# Kids & Family                           -0.011460          -0.000686
# Lifestyle                                0.017566          -0.004362
# Magazines & Newspapers                   0.009756          -0.000343
            0.039456 -0.000059  0.707086  0.017023 -0.000132
# MI                            0.039456  1.000000  0.707086  0.017023  0.447161
# MK                            0.101253  0.288582  0.408128  0.058987  0.645364
# ML                            0.233660  0.168862  0.238814  0.093879  0.377631
# MN                            0.088931  0.377898  0.534444  0.037305  0.845105
# MR                            0.261915  0.147247  0.208244  0.106537  0.329292
# MS                            0.788510  0.041067  0.058079  0.404937  0.091839
# MT                            0.055801  0.707086  1.000000  0.024074  0.316107
# MY                            0.088931 -0.000156  0.267112  0.045046  0.676014
# NB                            0.668154  0.037460  0.052978  0.432842  0.013946
# NE                            0.111622 -0.000166  0.249838  0.033675  0.632325
# NL                            0.530584  0.026845  0.037966  0.538979  0.060035
# NN                            0.108230 -0.000212  0.195903  0.061398 -0.000474
# NO                            0.094993 -0.000412 -0.000583  0.078315  0.255035
# OM                            0.068344 -0.000102  0.408164  0.005840 -0.000228
# OR                            0.068344 -0.000102  0.408164  0.005840 -0.000228
# PA                            0.219878  0.179447  0.253784  0.087500  0.079674
# PL                            0.544838  0.028448  0.040233  0.515896  0.063620
# PS                            0.068344  0.577316  0.816473  0.029486  0.258032
# PT                            0.498016  0.021489  0.030391  0.606627  0.048057
# QU                            0.039456 -0.000059  0.707086  0.017023 -0.000132
# RN                            0.039456 -0.000059  0.707086  0.017023 -0.000132
# RO                            0.609763  0.047841  0.067659  0.325676  0.106988
# RU                            0.469409  0.020004  0.028290  0.601518  0.044735
# RW                            0.039456 -0.000059  0.707086  0.017023 -0.000132
# SA                            0.068344 -0.000102  0.408164  0.005840 -0.000228
# SD                            0.068344 -0.000102  0.408164  0.005840 -0.000228
# SE                            0.007405 -0.000195  0.213006  0.000892 -0.000436
# SI                            0.104410 -0.000156  0.267112  0.045046  0.676014
# SK                            0.583584  0.049284  0.069700  0.323695  0.110215
# SL                            0.247296  0.142655  0.201751  0.110539  0.319025
# SO                            0.068344 -0.000102  0.408164  0.005840 -0.000228
# SQ                            0.106201  0.301423  0.426289  0.056474  0.674081
# SR                            0.148392  0.173914  0.245958  0.072904  0.388929
# SU                            0.039456 -0.000059  0.707086  0.017023 -0.000132
# SV                            0.537678  0.028785  0.040709  0.523838  0.064372
# SW                            0.104410  0.377898  0.534444  0.045046  0.845105
# TA                            0.259011  0.142655  0.201751  0.110539  0.319025
# TE                            0.236982  0.166495  0.235467  0.095409  0.372338
# TG                            0.055801 -0.000083  0.499941  0.024074 -0.000186
# TH                            0.781237  0.035852  0.050704  0.460986  0.080177
# TI                            0.039456 -0.000059  0.707086  0.017023 -0.000132
# TK                            0.055801 -0.000083  0.499941  0.024074 -0.000186
# TL                            0.157827  0.235584  0.333176  0.072257  0.526845
# TO                            0.039456 -0.000059  0.707086  0.017023 -0.000132
# TR                            0.574265  0.026042  0.036829  0.559223  0.058237
# TT                            0.039456 -0.000059  0.707086  0.017023 -0.000132
# UG                            0.039456 -0.000059  0.707086  0.017023 -0.000132
# UK                            0.582187  0.051779  0.073229  0.272414  0.115795
# UR                            0.143881  0.229294  0.324281  0.064839  0.102097
# UZ                            0.058444  0.499956  0.707065  0.023809  0.223403
# VI                            1.000000  0.039456  0.055801  0.409632  0.088237
# XH                            0.039456  1.000000  0.707086  0.017023  0.447161
# YI                            0.055801  0.707086  1.000000  0.024074  0.316107
# ZH                            0.409632  0.017023  0.024074  1.000000  0.038068
# ZU                            0.088237  0.447161  0.316107  0.038068  1.000000
#
# [171 rows x 171 columns]

# %%
corr_mat_full.loc['Medical', 'Size']
# Out:
# -0.0023097398029875214

# %%
sns.heatmap(corr_mat_full, square=True, cmap='coolwarm')
pass

# %% [markdown]
# К сожалению, признаки слабо коррелируются между собой.
# Хорошо коррелируются между собой языки, но это вряд ли поможет в решении поставленной задачи

# %% [markdown]
# Проделаем это для урезанных значений:

# %%
corr_mat = data_vis.corr()
corr_mat
# Out:
#                               Average User Rating  User Rating Count  \
# Average User Rating                      1.000000           0.007339
# User Rating Count                        0.007339           1.000000
# Price                                    0.010916          -0.003868
# In-app Purchases                        -0.024902           0.043768
# Size                                    -0.015571           0.040466
# Original Release Date                   -0.289427           0.041243
# Current Version Release Date            -0.188967          -0.038443
#
#                                  Price  In-app Purchases      Size  \
# Average User Rating           0.010916         -0.024902 -0.015571
# User Rating Count            -0.003868          0.043768  0.040466
# Price                         1.000000         -0.060968  0.033067
# In-app Purchases             -0.060968          1.000000  0.153478
# Size                          0.033067          0.153478  1.000000
# Original Release Date         0.006421          0.038206 -0.179474
# Current Version Release Date -0.004449         -0.033497 -0.226219
#
#                               Original Release Date  \
# Average User Rating                       -0.289427
# User Rating Count                          0.041243
# Price                                      0.006421
# In-app Purchases                           0.038206
# Size                                      -0.179474
# Original Release Date                      1.000000
# Current Version Release Date               0.607099
#
#                               Current Version Release Date
# Average User Rating                              -0.188967
# User Rating Count                                -0.038443
# Price                                            -0.004449
# In-app Purchases                                 -0.033497
# Size                                             -0.226219
# Original Release Date                             0.607099
# Current Version Release Date                      1.000000

# %%
sns.heatmap(corr_mat, square=True, cmap='coolwarm')

# %% [markdown]
# Видим много синего цвета - данные слабо коррелированы

# %%
corr_mat.where(np.triu(corr_mat > 0.5, k=1)).stack().sort_values(ascending=False)
# Out:
# Original Release Date  Current Version Release Date    0.607099
# dtype: float64

# %% [markdown]
# Видим что даты релиза и последнего обновления коррелируются хорошо, но поможет ли нам это решить задачу ?

# %% [markdown]
# Делаем вывод об очень слыбой корреляции признаков для урезанных данных.
# Проделаем это для полных данных

# %%
pd.options.display.max_rows = 2000

# %%
corr_mat_full.where(np.triu(corr_mat_full > 0.5, k=1)).stack().sort_values(ascending=False)
# Out:
# IU                     MG                              1.000000
# QU                     TI                              1.000000
#                        SU                              1.000000
# GD                     QU                              1.000000
# BO                     KS                              1.000000
# GD                     MG                              1.000000
# QU                     RW                              1.000000
#                        RN                              1.000000
# BO                     OM                              1.000000
# GD                     JV                              1.000000
# BO                     OR                              1.000000
# GD                     IU                              1.000000
#                        GV                              1.000000
#                        GN                              1.000000
# BO                     SA                              1.000000
# IU                     UG                              1.000000
# BO                     SD                              1.000000
#                        SO                              1.000000
# BR                     DZ                              1.000000
# KU                     YI                              1.000000
# BR                     FO                              1.000000
# FO                     UG                              1.000000
# BR                     GD                              1.000000
# DZ                     IU                              1.000000
# KU                     MT                              1.000000
# BR                     GV                              1.000000
# QU                     TO                              1.000000
# GD                     UG                              1.000000
# KS                     SA                              1.000000
#                        SD                              1.000000
#                        SO                              1.000000
# GD                     TT                              1.000000
#                        TO                              1.000000
#                        TI                              1.000000
# RN                     UG                              1.000000
#                        TT                              1.000000
#                        TO                              1.000000
# KU                     KY                              1.000000
# RN                     TI                              1.000000
# GD                     SU                              1.000000
# RN                     SU                              1.000000
# IU                     JV                              1.000000
# GD                     RW                              1.000000
#                        RN                              1.000000
# RN                     RW                              1.000000
# DZ                     JV                              1.000000
# QU                     UG                              1.000000
#                        TT                              1.000000
# BR                     GN                              1.000000
#                        IU                              1.000000
# MG                     RN                              1.000000
# FO                     RN                              1.000000
#                        QU                              1.000000
#                        MG                              1.000000
#                        JV                              1.000000
# IU                     TI                              1.000000
# OM                     SO                              1.000000
#                        SD                              1.000000
#                        SA                              1.000000
# KY                     YI                              1.000000
# DZ                     GN                              1.000000
# FO                     IU                              1.000000
# OM                     OR                              1.000000
# FO                     GV                              1.000000
# DZ                     GD                              1.000000
# FO                     GN                              1.000000
#                        GD                              1.000000
# DZ                     FO                              1.000000
# MG                     TO                              1.000000
#                        TI                              1.000000
#                        SU                              1.000000
#                        RW                              1.000000
# EU                     SW                              1.000000
# IU                     RW                              1.000000
# FO                     RW                              1.000000
# BR                     JV                              1.000000
# FO                     SU                              1.000000
# BR                     MG                              1.000000
#                        QU                              1.000000
#                        RN                              1.000000
# IU                     TT                              1.000000
# BR                     RW                              1.000000
# FO                     TT                              1.000000
# BR                     SU                              1.000000
# KY                     MT                              1.000000
# BR                     TI                              1.000000
# IU                     QU                              1.000000
# DZ                     GV                              1.000000
# FO                     TO                              1.000000
# IU                     TO                              1.000000
#                        RN                              1.000000
# BR                     TO                              1.000000
#                        TT                              1.000000
#                        UG                              1.000000
# FO                     TI                              1.000000
# OR                     SO                              1.000000
#                        SD                              1.000000
#                        SA                              1.000000
# MG                     TT                              1.000000
#                        UG                              1.000000
# KS                     OR                              1.000000
#                        OM                              1.000000
# DZ                     UG                              1.000000
# GV                     MG                              1.000000
# TG                     TK                              1.000000
# AS                     BO                              1.000000
#                        KS                              1.000000
# GV                     JV                              1.000000
# DZ                     TT                              1.000000
# GV                     IU                              1.000000
# AS                     OM                              1.000000
#                        OR                              1.000000
#                        SA                              1.000000
#                        SD                              1.000000
#                        SO                              1.000000
# AY                     BR                              1.000000
#                        DZ                              1.000000
# MT                     YI                              1.000000
# AY                     FO                              1.000000
#                        GD                              1.000000
# SU                     UG                              1.000000
#                        TT                              1.000000
#                        TO                              1.000000
# GV                     QU                              1.000000
#                        RN                              1.000000
#                        RW                              1.000000
#                        TO                              1.000000
# JV                     MG                              1.000000
# GV                     UG                              1.000000
#                        TT                              1.000000
# TT                     UG                              1.000000
# JV                     QU                              1.000000
#                        RN                              1.000000
#                        RW                              1.000000
# TO                     UG                              1.000000
#                        TT                              1.000000
# GV                     TI                              1.000000
# JV                     UG                              1.000000
#                        SU                              1.000000
#                        TI                              1.000000
# GV                     SU                              1.000000
# JV                     TO                              1.000000
# TI                     UG                              1.000000
#                        TT                              1.000000
#                        TO                              1.000000
# EU                     GL                              1.000000
# JV                     TT                              1.000000
# AY                     GN                              1.000000
# SU                     TI                              1.000000
# AY                     GV                              1.000000
# SA                     SO                              1.000000
# GN                     RN                              1.000000
#                        QU                              1.000000
# DZ                     RW                              1.000000
# SD                     SO                              1.000000
# GN                     MG                              1.000000
# KM                     LO                              1.000000
# GN                     JV                              1.000000
# DZ                     RN                              1.000000
#                        QU                              1.000000
# SA                     SD                              1.000000
# AZ                     KA                              1.000000
# GN                     IU                              1.000000
# RW                     UG                              1.000000
#                        TT                              1.000000
#                        TO                              1.000000
#                        TI                              1.000000
#                        SU                              1.000000
# DZ                     MG                              1.000000
# GN                     GV                              1.000000
# GL                     SW                              1.000000
# AY                     IU                              1.000000
# GN                     RW                              1.000000
#                        SU                              1.000000
#                        TI                              1.000000
# AY                     JV                              1.000000
#                        MG                              1.000000
# DZ                     TO                              1.000000
# AY                     QU                              1.000000
#                        RN                              1.000000
#                        RW                              1.000000
#                        SU                              1.000000
# IU                     SU                              1.000000
# AY                     TI                              1.000000
# KK                     UZ                              1.000000
# GN                     UG                              1.000000
# AY                     TO                              1.000000
#                        TT                              1.000000
#                        UG                              1.000000
# MI                     XH                              1.000000
# GN                     TT                              1.000000
# DZ                     TI                              1.000000
#                        SU                              1.000000
# GN                     TO                              1.000000
# MG                     QU                              1.000000
# KN                     MR                              0.989275
# ML                     TE                              0.985984
# KN                     TA                              0.979321
# MR                     TA                              0.968819
# AZ                     BE                              0.942781
# BE                     KA                              0.942781
# AZ                     GL                              0.935387
#                        SW                              0.935387
# KA                     SW                              0.935387
# EU                     IS                              0.935387
#                        KA                              0.935387
# AZ                     EU                              0.935387
# IS                     SW                              0.935387
# GL                     IS                              0.935387
#                        KA                              0.935387
# KA                     MN                              0.935387
# AZ                     MN                              0.935387
# GU                     MR                              0.932611
# BN                     KN                              0.928075
# PA                     TE                              0.927824
# KM                     MY                              0.925793
# LO                     MY                              0.925793
# GU                     KN                              0.922607
# DA                     NB                              0.920173
#                        FI                              0.919909
# LV                     TE                              0.919079
# BN                     MR                              0.917232
# AM                     LO                              0.912844
#                        KM                              0.912844
# ML                     PA                              0.910595
# FI                     NB                              0.909179
# EL                     FI                              0.909050
# BN                     TA                              0.908872
# LV                     ML                              0.904671
# GU                     TA                              0.903527
# NL                     SV                              0.900399
# HU                     SK                              0.899349
# Gaming                 Stickers                        0.897868
# HU                     RO                              0.896399
# CA                     SK                              0.893533
# BE                     SW                              0.881865
#                        GL                              0.881865
#                        EU                              0.881865
#                        MN                              0.881865
# RO                     SK                              0.881557
# DE                     FR                              0.880895
# EL                     NB                              0.879043
# DA                     EL                              0.877020
# IS                     KA                              0.874941
# AZ                     IS                              0.874941
# KN                     TE                              0.874906
# BN                     GU                              0.872537
# ML                     MR                              0.871996
# MK                     SQ                              0.870301
# ES                     FR                              0.868269
# LA                     SD                              0.866000
#                        SA                              0.866000
#                        OM                              0.866000
#                        SO                              0.866000
#                        OR                              0.866000
# KS                     LA                              0.866000
# BO                     LA                              0.866000
# AS                     LA                              0.866000
# PS                     UZ                              0.866000
# KK                     PS                              0.866000
# KN                     ML                              0.862644
# MR                     TE                              0.859758
# GL                     MN                              0.857084
# EU                     MN                              0.857084
# MN                     SW                              0.857084
# GL                     SI                              0.857084
# SI                     SW                              0.857084
# EU                     SI                              0.857084
# TA                     TE                              0.856815
# ES                     IT                              0.854474
# CA                     RO                              0.854399
# DE                     ES                              0.849552
# IT                     PT                              0.849308
# GL                     ZU                              0.845105
# SW                     ZU                              0.845105
# EU                     ZU                              0.845105
# MN                     ZU                              0.845105
# AM                     SI                              0.845105
#                        EU                              0.845105
#                        GL                              0.845105
#                        SW                              0.845105
#                        MY                              0.845105
#                        MN                              0.845105
# CS                     PL                              0.844977
# ML                     TA                              0.844806
# LV                     PA                              0.844634
# FR                     IT                              0.841751
# ES                     PT                              0.836217
# CA                     HU                              0.833840
# GU                     PA                              0.831073
# CS                     SV                              0.830559
# JA                     KO                              0.827962
# EL                     MS                              0.827872
# HE                     NB                              0.825909
# BE                     IS                              0.824871
# BN                     TE                              0.824548
# DE                     IT                              0.822010
# EO                     KY                              0.816473
#                        YI                              0.816473
#                        MT                              0.816473
#                        KU                              0.816473
# PS                     TG                              0.816473
#                        TK                              0.816473
# KU                     PS                              0.816473
# KY                     PS                              0.816473
# PS                     YI                              0.816473
# MT                     PS                              0.816473
# ET                     IS                              0.816401
# FI                     MS                              0.816122
# PL                     SV                              0.815230
# EL                     HE                              0.812372
# BN                     ML                              0.812326
# KN                     PA                              0.811759
# LV                     SL                              0.810643
# SL                     TE                              0.809076
# GU                     ML                              0.808118
# FI                     HE                              0.808116
# PT                     RU                              0.807486
# MS                     TH                              0.804500
# DA                     HE                              0.804134
# KN                     LV                              0.804047
# FR                     PT                              0.803728
# DE                     RU                              0.802838
# FR                     RU                              0.802086
# AZ                     SI                              0.801697
# KA                     SI                              0.801697
# NE                     SW                              0.801697
# EU                     NE                              0.801697
# NE                     SI                              0.801697
# GL                     NE                              0.801697
# IS                     SI                              0.801697
#                        MN                              0.801697
# BG                     KN                              0.801649
# AM                     ZU                              0.799941
# ES                     RU                              0.799653
# SQ                     SW                              0.797630
# GL                     SQ                              0.797630
# EU                     SQ                              0.797630
# SI                     SQ                              0.797630
# NL                     TR                              0.797515
#                        PL                              0.797464
# IT                     RU                              0.797093
# GU                     TE                              0.796775
# SV                     TR                              0.796527
# ML                     SL                              0.796392
# PA                     TA                              0.794973
# MR                     PA                              0.794018
# BG                     MR                              0.791871
# MS                     NB                              0.791094
# DA                     MS                              0.790548
# AM                     NE                              0.790500
#                        AZ                              0.790500
#                        IS                              0.790500
#                        KA                              0.790500
# AZ                     ZU                              0.790500
# IS                     ZU                              0.790500
# KA                     ZU                              0.790500
# DE                     PT                              0.790108
# LV                     MR                              0.788792
# MS                     VI                              0.788510
# LV                     TA                              0.787409
# BG                     TA                              0.785030
# DA                     SV                              0.784958
# CS                     NL                              0.784147
# ET                     SQ                              0.783203
# HE                     SK                              0.782383
# PT                     TR                              0.782005
# TH                     VI                              0.781237
# BN                     LV                              0.779467
# BG                     BN                              0.777096
# LO                     SI                              0.771431
# KM                     SI                              0.771431
# EU                     LO                              0.771431
# KM                     SW                              0.771431
# EU                     KM                              0.771431
# GL                     LO                              0.771431
#                        KM                              0.771431
# LO                     SW                              0.771431
#                        MN                              0.771431
# KM                     MN                              0.771431
# PL                     TR                              0.770328
# CA                     HE                              0.764535
# EU                     MK                              0.763650
# MK                     SW                              0.763650
#                        SI                              0.763650
# GL                     MK                              0.763650
# ET                     EU                              0.763650
#                        SI                              0.763650
#                        SW                              0.763650
#                        GL                              0.763650
# CS                     TR                              0.763428
# BN                     PA                              0.761499
# NL                     PT                              0.760397
# GA                     LA                              0.755862
# BE                     SI                              0.755818
# IT                     TR                              0.753591
# BG                     GU                              0.751523
# EL                     HU                              0.751273
# KA                     NE                              0.749882
# IS                     NE                              0.749882
# AZ                     NE                              0.749882
# ET                     MK                              0.749823
# IT                     NL                              0.749455
# KO                     PT                              0.748715
# EL                     TH                              0.747670
# IS                     SQ                              0.746068
# KA                     SQ                              0.746068
# AZ                     SQ                              0.746068
# NB                     SV                              0.745548
# BE                     ZU                              0.745268
# AM                     BE                              0.745268
# PA                     SL                              0.743536
# EL                     SK                              0.741116
# FI                     SV                              0.740742
# EL                     RO                              0.740332
# FI                     HU                              0.739504
#                        TH                              0.736673
# PT                     SV                              0.736097
# RO                     UK                              0.734405
# HE                     HU                              0.734095
# AF                     EU                              0.733670
#                        GL                              0.733670
#                        SI                              0.733670
#                        SW                              0.733670
# FI                     SK                              0.733652
# DA                     NL                              0.731876
# LO                     ZU                              0.730211
# KM                     ZU                              0.730211
# KO                     RU                              0.730151
# BG                     LV                              0.729284
# RU                     TR                              0.728545
# FI                     RO                              0.726872
# IT                     KO                              0.726263
# GU                     LV                              0.725265
# NB                     TH                              0.724412
# DA                     TH                              0.723291
# HE                     MS                              0.722489
# LO                     NE                              0.721577
# KM                     NE                              0.721577
# KA                     KM                              0.721577
# IS                     KM                              0.721577
# AZ                     KM                              0.721577
# IS                     LO                              0.721577
# AZ                     LO                              0.721577
# KA                     LO                              0.721577
# AF                     MK                              0.720372
# IT                     SV                              0.718818
# EL                     SV                              0.718065
# HE                     RO                              0.717520
# JA                     ZH                              0.715843
# KA                     MK                              0.714278
# IS                     MK                              0.714278
# AZ                     MK                              0.714278
#                        ET                              0.714278
# ET                     KA                              0.714278
# GL                     MY                              0.714168
# MY                     SW                              0.714168
# EU                     MY                              0.714168
# MY                     SI                              0.714168
# MN                     SI                              0.714168
#                        MY                              0.714168
# FR                     KO                              0.712274
# ES                     KO                              0.711205
# CS                     HE                              0.709535
# PL                     PT                              0.708072
# KN                     SL                              0.707663
# BG                     TE                              0.707592
# MI                     MT                              0.707086
# KY                     XH                              0.707086
# MT                     XH                              0.707086
# MI                     YI                              0.707086
# XH                     YI                              0.707086
# KY                     MI                              0.707086
# KU                     XH                              0.707086
#                        MI                              0.707086
# FO                     TK                              0.707086
#                        TG                              0.707086
# GV                     TG                              0.707086
# DZ                     TK                              0.707086
#                        TG                              0.707086
# GD                     TG                              0.707086
# BR                     TK                              0.707086
# GD                     TK                              0.707086
# BR                     TG                              0.707086
# GN                     TG                              0.707086
# AY                     TK                              0.707086
#                        TG                              0.707086
# GV                     TK                              0.707086
# GN                     TK                              0.707086
# TG                     TT                              0.707086
# IU                     TK                              0.707086
# TK                     TT                              0.707086
#                        TO                              0.707086
# TI                     TK                              0.707086
# TG                     UG                              0.707086
#                        TO                              0.707086
#                        TI                              0.707086
# SU                     TK                              0.707086
#                        TG                              0.707086
# QU                     TG                              0.707086
#                        TK                              0.707086
# RN                     TG                              0.707086
#                        TK                              0.707086
# KK                     TK                              0.707065
# TK                     UZ                              0.707065
# TG                     UZ                              0.707065
# KK                     TG                              0.707065
# AZ                     UZ                              0.707024
# KA                     UZ                              0.707024
#                        KK                              0.707024
# AZ                     KK                              0.707024
# ET                     KM                              0.706982
#                        LO                              0.706982
# BE                     NE                              0.706961
# SK                     UK                              0.706093
# EL                     VI                              0.706007
# HU                     NB                              0.705979
# NB                     NL                              0.705300
#                        SK                              0.704931
# HU                     UK                              0.703505
# BE                     SQ                              0.703355
# FR                     JA                              0.702993
# DA                     HU                              0.701703
# KO                     ZH                              0.700864
# DE                     KO                              0.700754
# NB                     RO                              0.700668
# DA                     SK                              0.698505
# NL                     RU                              0.697856
# FI                     VI                              0.697730
# FA                     TA                              0.697374
# BG                     ML                              0.696497
# FA                     KN                              0.695902
# DA                     RO                              0.695434
# Emoji & Expressions    Stickers                        0.695281
# JA                     PT                              0.694808
# CA                     UK                              0.694501
# MR                     SL                              0.694231
# IT                     PL                              0.694136
# ES                     TR                              0.693756
#                        JA                              0.693587
# SL                     TA                              0.692993
# KO                     TR                              0.692624
# DE                     JA                              0.691899
# FI                     NL                              0.689516
# CA                     EL                              0.688926
# KO                     NL                              0.687665
# FA                     MR                              0.687039
# CA                     FI                              0.686759
# ES                     NL                              0.686647
# HE                     VI                              0.686250
# AF                     AZ                              0.686231
#                        IS                              0.686231
#                        KA                              0.686231
# MN                     SQ                              0.683609
# IT                     JA                              0.682578
# BE                     LO                              0.680282
#                        KM                              0.680282
# JA                     RU                              0.679459
# EL                     NL                              0.676423
# SI                     ZU                              0.676014
# MY                     ZU                              0.676014
# FR                     TR                              0.674533
# KO                     SV                              0.674520
# AM                     SQ                              0.674081
# SQ                     ZU                              0.674081
# BE                     MK                              0.673380
#                        ET                              0.673380
# DA                     VI                              0.671353
# PL                     RU                              0.670959
# FR                     NL                              0.670161
# RU                     SV                              0.669482
# AF                     SQ                              0.668762
# DA                     PL                              0.668556
# NB                     VI                              0.668154
# MN                     NE                              0.668008
# MY                     NE                              0.668008
# AZ                     MY                              0.668008
# KA                     MY                              0.668008
# IS                     MY                              0.668008
# EO                     PS                              0.666608
# BE                     KK                              0.666569
#                        UZ                              0.666569
# BN                     SL                              0.665728
# EL                     TR                              0.665174
# DE                     TR                              0.664972
# DA                     TR                              0.663342
# AR                     RO                              0.662489
# CS                     EL                              0.662278
# CA                     NB                              0.661907
# CS                     NB                              0.661340
# BG                     SL                              0.659613
# CS                     FI                              0.659131
# BN                     FA                              0.658762
# NB                     TR                              0.658729
# DE                     NL                              0.658328
# SR                     TL                              0.656039
# AR                     UK                              0.654712
# EU                     PS                              0.654577
# GL                     PS                              0.654577
# PS                     SW                              0.654577
# GA                     PS                              0.654577
#                        SA                              0.654577
# AS                     GA                              0.654577
# GA                     SO                              0.654577
#                        OM                              0.654577
#                        KS                              0.654577
#                        OR                              0.654577
# BO                     GA                              0.654577
# GA                     SD                              0.654577
# MK                     MN                              0.654480
# ET                     MN                              0.654480
#                        MY                              0.654480
# CS                     DA                              0.653374
# CA                     DA                              0.652595
# CS                     TH                              0.529089
# AR                     FI                              0.528882
# NL                     SK                              0.528584
# TL                     ZU                              0.526845
# AM                     TL                              0.526845
# NB                     RU                              0.526836
# HR                     HU                              0.525499
# CA                     PL                              0.525180
# SQ                     SR                              0.524422
# AF                     MY                              0.523890
# SV                     ZH                              0.523838
# DA                     ES                              0.523685
# TA                     UR                              0.523632
# RU                     TH                              0.523549
# PL                     TH                              0.523505
# RO                     TR                              0.522118
# PS                     SQ                              0.522110
# AR                     NB                              0.522071
# BG                     SR                              0.521017
# HI                     LV                              0.520865
#                        TE                              0.520754
# HU                     TR                              0.520636
# FI                     RU                              0.520213
# GU                     HR                              0.520095
# AR                     DA                              0.520072
# GA                     UR                              0.519985
# HR                     LV                              0.518887
# EL                     KO                              0.517807
# PL                     ZH                              0.515896
# Emoji & Expressions    Gaming                          0.515866
# IS                     LT                              0.515719
# KA                     LT                              0.515719
# AZ                     LT                              0.515719
# HI                     ML                              0.513455
# DA                     FR                              0.511496
# MS                     PT                              0.510920
# EL                     RU                              0.508724
# CS                     UK                              0.507250
# MR                     UR                              0.506613
# JA                     TH                              0.506565
# SK                     TR                              0.505543
# DA                     DE                              0.502180
# ET                     SR                              0.502013
# AR                     TR                              0.501222
# ES                     NB                              0.500008
# dtype: float64

# %% [markdown]
# Большинство корреляций связывают между собой наличие языков, однако есть несколько и других признаков, например,
# Gaming                 Stickers                        0.897868
# Emoji & Expressions    Stickers                        0.695281

# %% [markdown]
# ### Удаление признаков с очень слабой корреляцией

# %%
corr_mat_full.loc[:, 'Age Rating'].sort_values(ascending=False)
# Out:
# Age Rating                      1.000000
# Puzzle                          0.081639
# Current Version Release Date    0.074395
# Casual                          0.055209
# Family                          0.049809
# Original Release Date           0.039482
# Price                           0.038808
# Education                       0.027066
# HE                              0.022581
# EL                              0.022525
# FI                              0.021437
# Board                           0.021339
# NB                              0.021254
# Average User Rating             0.018507
# DA                              0.018136
# HU                              0.017786
# Racing                          0.016306
# SK                              0.015949
# Utilities                       0.013563
# MS                              0.011838
# Word                            0.011834
# VI                              0.011485
# Trivia                          0.011275
# Entertainment                   0.011086
# Health & Fitness                0.009120
# Lifestyle                       0.008180
# HY                              0.007705
# User Rating Count               0.007664
# NO                              0.007632
# RO                              0.007215
# Adventure                       0.006667
# Productivity                    0.006489
# CA                              0.005513
# TL                              0.003203
# ZU                              0.002869
# Sports & Activities             0.002566
# Places & Objects                0.002566
# Animals & Nature                0.002566
# SR                              0.002405
# People                          0.002222
# Kids & Family                   0.002222
# Art                             0.001814
# Comics & Cartoons               0.001814
# Travel                          0.001527
# Magazines & Newspapers          0.001283
# Weather                         0.001283
# XH                              0.001283
# MI                              0.001283
# UR                              0.001229
# Photo & Video                   0.000708
# KA                              0.000266
# AZ                              0.000266
# Music                          -0.000100
# SI                             -0.000201
# MN                             -0.000201
# AF                             -0.000650
# HI                             -0.000993
# MK                             -0.001047
# Strategy                       -0.001283
# Stickers                       -0.001399
# LT                             -0.001781
# CY                             -0.002190
# UZ                             -0.002190
# KK                             -0.002190
# Shopping                       -0.002190
# Finance                        -0.002829
# NE                             -0.003097
# IS                             -0.003097
# Gaming                         -0.003099
# EU                             -0.003796
# GL                             -0.003796
# SW                             -0.003796
# Navigation                     -0.004856
# KR                             -0.004911
# HR                             -0.005017
# AM                             -0.005639
# BE                             -0.005663
# SV                             -0.006152
# EN                             -0.006501
# LA                             -0.006945
# Business                       -0.006999
# BN                             -0.007079
# SQ                             -0.007218
# Emoji & Expressions            -0.007313
# GA                             -0.007391
# Food & Drink                   -0.007964
# Card                           -0.008256
# FA                             -0.008552
# CS                             -0.008645
# PS                             -0.008760
# EO                             -0.008760
# KS                             -0.008760
# SO                             -0.008760
# OR                             -0.008760
# OM                             -0.008760
# AS                             -0.008760
# BO                             -0.008760
# SD                             -0.008760
# SA                             -0.008760
# ET                             -0.009286
# ZH                             -0.009739
# TA                             -0.010055
# TH                             -0.010570
# KN                             -0.010641
# MR                             -0.010945
# Reference                      -0.011099
# Developer                      -0.011190
# SL                             -0.011416
# KU                             -0.011636
# KY                             -0.011636
# MT                             -0.011636
# YI                             -0.011636
# TK                             -0.011636
# TG                             -0.011636
# KL                             -0.011636
# Social Networking              -0.011909
# GU                             -0.012246
# BS                             -0.012390
# KM                             -0.012390
# LO                             -0.012390
# BG                             -0.013539
# LV                             -0.013706
# TE                             -0.014509
# JA                             -0.014783
# ML                             -0.014932
# PA                             -0.015077
# Sports                         -0.015512
# SE                             -0.015823
# NN                             -0.016482
# NL                             -0.016828
# UK                             -0.016992
# SU                             -0.017738
# TI                             -0.017738
# RW                             -0.017738
# TO                             -0.017738
# MG                             -0.017738
# TT                             -0.017738
# UG                             -0.017738
# RN                             -0.017738
# JV                             -0.017738
# QU                             -0.017738
# IU                             -0.017738
# GD                             -0.017738
# AY                             -0.017738
# BR                             -0.017738
# FO                             -0.017738
# DZ                             -0.017738
# GV                             -0.017738
# GN                             -0.017738
# MY                             -0.018177
# AR                             -0.020382
# Primary Genre                  -0.020462
# TR                             -0.024480
# KO                             -0.024698
# News                           -0.029420
# PL                             -0.030358
# Medical                        -0.032558
# In-app Purchases               -0.033215
# Simulation                     -0.036904
# Books                          -0.038418
# FR                             -0.042710
# DE                             -0.043460
# IT                             -0.045490
# ES                             -0.050845
# RU                             -0.053475
# PT                             -0.055035
# Casino                         -0.072510
# Role Playing                   -0.075410
# Action                         -0.106262
# Size                           -0.140797
# Games                                NaN
# Name: Age Rating, dtype: float64

# %% [markdown]
# # Бинаризация номинальных признаков

# %%
data_raw.describe(include=['category'])
# Out:
#                                          Developer Age Rating Primary Genre
# count                                        17007      17007         17007
# unique                                        8693          4            21
# top     Tapps Tecnologia da Informa\xe7\xe3o Ltda.         4+         Games
# freq                                           123      11806         16286

# %% [markdown]
# У нас есть три категориальных признака, их нужно преобразовать в числовой(бинарный)
# Age Rating - лейбл

# %%
primary_genre = pd.get_dummies(data_raw['Primary Genre'])

# %%
primary_genre[-20:]
# Out:
#        Book  Business  Education  Entertainment  Finance  Food & Drink  Games  \
# 16987     0         0          0              0        0             0      1
# 16988     0         0          0              0        0             0      1
# 16989     0         0          0              0        0             0      1
# 16990     0         0          0              0        0             0      1
# 16991     0         0          0              0        0             0      1
# 16992     0         0          0              0        0             0      1
# 16993     0         0          0              0        0             0      1
# 16994     0         0          0              1        0             0      0
# 16995     0         0          0              0        0             0      1
# 16996     0         0          0              0        0             0      1
# 16997     0         0          0              0        0             0      1
# 16998     0         0          0              0        0             0      1
# 16999     0         0          0              0        0             0      1
# 17000     0         0          0              0        0             0      1
# 17001     0         0          0              0        0             0      1
# 17002     0         0          0              0        0             0      1
# 17003     0         0          0              0        0             0      1
# 17004     0         0          0              0        0             0      1
# 17005     0         0          0              0        0             0      1
# 17006     0         0          0              0        0             0      1
#
#        Health & Fitness  Lifestyle  Medical  ...  Navigation  News  \
# 16987                 0          0        0  ...           0     0
# 16988                 0          0        0  ...           0     0
# 16989                 0          0        0  ...           0     0
# 16990                 0          0        0  ...           0     0
# 16991                 0          0        0  ...           0     0
# 16992                 0          0        0  ...           0     0
# 16993                 0          0        0  ...           0     0
# 16994                 0          0        0  ...           0     0
# 16995                 0          0        0  ...           0     0
# 16996                 0          0        0  ...           0     0
# 16997                 0          0        0  ...           0     0
# 16998                 0          0        0  ...           0     0
# 16999                 0          0        0  ...           0     0
# 17000                 0          0        0  ...           0     0
# 17001                 0          0        0  ...           0     0
# 17002                 0          0        0  ...           0     0
# 17003                 0          0        0  ...           0     0
# 17004                 0          0        0  ...           0     0
# 17005                 0          0        0  ...           0     0
# 17006                 0          0        0  ...           0     0
#
#        Productivity  Reference  Shopping  Social Networking  Sports  Stickers  \
# 16987             0          0         0                  0       0         0
# 16988             0          0         0                  0       0         0
# 16989             0          0         0                  0       0         0
# 16990             0          0         0                  0       0         0
# 16991             0          0         0                  0       0         0
# 16992             0          0         0                  0       0         0
# 16993             0          0         0                  0       0         0
# 16994             0          0         0                  0       0         0
# 16995             0          0         0                  0       0         0
# 16996             0          0         0                  0       0         0
# 16997             0          0         0                  0       0         0
# 16998             0          0         0                  0       0         0
# 16999             0          0         0                  0       0         0
# 17000             0          0         0                  0       0         0
# 17001             0          0         0                  0       0         0
# 17002             0          0         0                  0       0         0
# 17003             0          0         0                  0       0         0
# 17004             0          0         0                  0       0         0
# 17005             0          0         0                  0       0         0
# 17006             0          0         0                  0       0         0
#
#        Travel  Utilities
# 16987       0          0
# 16988       0          0
# 16989       0          0
# 16990       0          0
# 16991       0          0
# 16992       0          0
# 16993       0          0
# 16994       0          0
# 16995       0          0
# 16996       0          0
# 16997       0          0
# 16998       0          0
# 16999       0          0
# 17000       0          0
# 17001       0          0
# 17002       0          0
# 17003       0          0
# 17004       0          0
# 17005       0          0
# 17006       0          0
#
# [20 rows x 21 columns]

# %%
data_raw = pd.concat((data_raw, primary_genre), axis=1)
data_raw = data_raw.drop(['Primary Genre'], axis=1)

# %%
developer = pd.get_dummies(data_raw['Developer'])

# %%
data_raw = pd.concat((data_raw, developer), axis=1)
data_raw = data_raw.drop(['Developer'], axis=1)

# %%
data_raw.columns
# Out:
# Index(['Average User Rating', 'User Rating Count', 'Price', 'In-app Purchases',
#        'Age Rating', 'Size', 'Original Release Date',
#        'Current Version Release Date', 'Action', 'Adventure',
#        ...
#        'zhiguo lin', 'zhijuan zhang', 'zhili zhao', 'zhixiang zhao',
#        'zhong chen', 'zhou zhimeng', 'zinWorks Studios (zinCode, LLC)',
#        'zomido med', 'zuiyouqu youxi', 'zurab inaishvili'],
#       dtype='object', length=8883)

# %%
data_raw['Age Rating'].unique()
# Out:
# [4+, 9+, 12+, 17+]
# Categories (4, object): [4+, 9+, 12+, 17+]

# %%
le = preprocessing.LabelEncoder()

# %%
fit_labels = pd.unique(data_raw['Age Rating'])
le.fit(fit_labels)
data_raw['Age Rating'] = le.transform(data_raw['Age Rating'])

# %% [markdown]
# # Нормализация количественных признаков

# %% [markdown]
# ### Проведем ее в следующем разделе

# %% [markdown]
# # Разобьем данные на обучающую и тестовую выборки

# %% [markdown]
#  в пропорции 3:1 (75% - обучающая выборка, 25% - тестовая):

# %%
y = data_raw.loc[:,'Age Rating']
x = data_raw.loc[:,:]

# %% [markdown]
# Нормализуем числовые признаки:

# %%
x = (x - x.mean(axis = 0))/x.std(axis = 0)

# %%
y.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Age Rating, dtype: int32

# %%
x.columns[x.isna().any()].tolist()
# Out:
# ['Games']

# %% [markdown]
# Каким образом произошло то, что в столбце Games обнаружено Nan - я понять так и не смог

# %%
# удаляем строки, в которых встречается Nan

x.dropna()
# Out:
# Empty DataFrame
# Columns: [Average User Rating, User Rating Count, Price, In-app Purchases, Age Rating, Size, Original Release Date, Current Version Release Date, Action, Adventure, Animals & Nature, Art, Board, Books, Business, Card, Casino, Casual, Comics & Cartoons, Education, Emoji & Expressions, Entertainment, Family, Finance, Food & Drink, Games, Gaming, Health & Fitness, Kids & Family, Lifestyle, Magazines & Newspapers, Medical, Music, Navigation, News, People, Photo & Video, Places & Objects, Productivity, Puzzle, Racing, Reference, Role Playing, Shopping, Simulation, Social Networking, Sports, Sports & Activities, Stickers, Strategy, Travel, Trivia, Utilities, Weather, Word, AF, AM, AR, AS, AY, AZ, BE, BG, BN, BO, BR, BS, CA, CS, CY, DA, DE, DZ, EL, EN, EO, ES, ET, EU, FA, FI, FO, FR, GA, GD, GL, GN, GU, GV, HE, HI, HR, HU, HY, IS, IT, IU, JA, JV, KA, ...]
# Index: []
#
# [0 rows x 8883 columns]

# %%
x.columns[x.isna().any()].tolist()
# Out:
# ['Games']

# %% [markdown]
# Как мы видим, нам это не помогло.
# Попробовав разные сопособы, я решил распрошаться с данным столбцом, так как он не несет в себе чего-то важного (и плохо коррелируется)

# %%
x.drop(['Games'], axis='columns', inplace=True)

# %%
x.columns[x.isna().any()].tolist()
# Out:
# []

# %% [markdown]
# Ура, Nan снова пропал из нашего dataFrame

# %%
x.drop(['Age Rating'], axis='columns', inplace=True)
# удалили лейбл значение из тестовой выборки

# %%
print(x.shape)
print(y.shape)
N, d = x.shape
# Out:
# (17007, 8880)
# (17007,)

# %%
from sklearn.preprocessing import label_binarize, LabelEncoder
le = LabelEncoder()
fit_labels = pd.unique(y)

# %%
# le.fit(fit_labels)
# y = le.transform(y)
# classes = np.unique(y)
# y = label_binarize(y, classes=classes)
# n_classes = y.shape[1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

N_train, _ = x_train.shape 
N_test,  _ = x_test.shape 

print(N_train, N_test)
# Out:
# 12755 4252

# %% [markdown]
# # Алгоритм Ближайших Соседей

# %%
# Out:
# 12755 4252

# %%
knn = KNeighborsClassifier(algorithm='ball_tree', n_neighbors = 5)

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
err_train = np.mean(y_train != knn.predict(x_train))  
err_test  = np.mean(y_test  != knn.predict(x_test))

# %%
print(err_train, err_test)
# Out:
# 0.23943551548412387 0.270931326434619

# %% [markdown]
# Для другого количества соседей

# %%
model = KNeighborsClassifier(n_neighbors=8).fit(x_train, y_train)
pred_y = model.predict(x_test)

# %%
print("R2-SCORE ", r2_score(y_test, pred_y)) 
print("ACCURACY ", accuracy_score(y_test, pred_y))

# %%
model2 = KNeighborsClassifier(n_neighbors=5).fit(x_train, y_train)
pred_y2 = model2.predict(x_test)

# %%
print("R2-SCORE ", r2_score(y_test, pred_y2)) 
print("ACCURACY ", accuracy_score(y_test, pred_y2))

# %%
# %%time
model3 = KNeighborsClassifier(n_neighbors=15).fit(x_train, y_train)
pred_y3 = model3.predict(x_test)

# %%
print("R2-SCORE ", r2_score(y_test, pred_y3)) 
print("ACCURACY ", accuracy_score(y_test, pred_y3))

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.333, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=1000).fit(x_train, y_train)
pred_y = model.predict(x_test) 

print("R2-SCORE ", r2_score(y_test, pred_y)) 
print("ACCURACY ", accuracy_score(y_test, pred_y))

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline

# %%
x_tr = x_train.copy()

# %%
# %%time
pca_model = PCA(n_components = 2)
pca_model.fit(x)
print(x.shape)
print(f"Главные компоненты:\n {pca_model.components_.shape}")
print(f"Дисперсии по главным компонентам:\n {pca_model.explained_variance_}")
# Out:
# (17007, 8880)
# Главные компоненты:
#  (2, 8880)
# Дисперсии по главным компонентам:
#  [36.52599453 19.6920082 ]
# CPU times: user 17.4 s, sys: 528 ms, total: 17.9 s
# Wall time: 10.6 s

# %%
x_proj = pca_model.transform(x)
print(x.shape)
print(x_proj.shape)
# Out:
# (17007, 8880)
# (17007, 2)

# %%
plt.figure(figsize = (8, 6))
colors = ['b', 'r', 'g', 'y']
for k in range(4):
    plt.scatter(x_proj[y == k, 0], x_proj[y == k, 1], color = colors[k], alpha = 0.4, label = str(k))
plt.legend()

# %%
from sklearn.svm import SVC

# %%
svm = SVC()

# %%
svm.fit(x_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print("Train accuracy: {}. Test accuracy: {}".format(svm.score(x_train, y_train), svm.score(x_test, y_test)))
# Out:
# Train accuracy: 0.9146217169737358. Test accuracy: 0.7476481655691439

# %%
results = pd.DataFrame(columns = ["Components", "Train_acc", "Test_acc"])

# %%
# %%time
for n_comp in range(1, 25):
    pca = PCA(n_components=n_comp)
    x_pca = pca.fit_transform(x)
    x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size = 0.25, random_state = 42)
    svm = SVC()
    svm.fit(x_train, y_train)
    comp_result = {"Components": n_comp, "Train_acc" : svm.score(x_train, y_train), "Test_acc" : svm.score(x_test, y_test)}
    results = results.append(comp_result, ignore_index=True)
# Out:
# CPU times: user 12min 58s, sys: 8.74 s, total: 13min 6s
# Wall time: 9min 30s

# %%
results
# Out:
#     Components  Train_acc  Test_acc
# 0          1.0   0.694551  0.694967
# 1          2.0   0.695257  0.694732
# 2          3.0   0.695335  0.694732
# 3          4.0   0.695335  0.694732
# 4          5.0   0.695414  0.694732
# 5          6.0   0.695492  0.694732
# 6          7.0   0.695414  0.694732
# 7          8.0   0.695492  0.694732
# 8          9.0   0.695806  0.694967
# 9         10.0   0.695806  0.695202
# 10        11.0   0.699726  0.695673
# 11        12.0   0.701058  0.696613
# 12        13.0   0.701215  0.696378
# 13        14.0   0.703018  0.697789
# 14        15.0   0.705762  0.701082
# 15        16.0   0.703646  0.697789
# 16        17.0   0.702626  0.698024
# 17        18.0   0.705214  0.697789
# 18        19.0   0.704508  0.698260
# 19        20.0   0.706076  0.699436
# 20        21.0   0.705057  0.698730
# 21        22.0   0.705841  0.700376
# 22        23.0   0.704508  0.698495
# 23        24.0   0.708742  0.701552

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(results.Components, results.Train_acc, label="Train")
plt.plot(results.Components, results.Test_acc, label = "Test")
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# %%time
for n_comp in range(26, 30):
    pca = PCA(n_components=n_comp)
    x_pca = pca.fit_transform(x)
    x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size = 0.25, random_state = 42)
    svm = SVC()
    svm.fit(x_train, y_train)
    comp_result = {"Components": n_comp, "Train_acc" : svm.score(x_train, y_train), "Test_acc" : svm.score(x_test, y_test)}
    results = results.append(comp_result, ignore_index=True)
# Out:
# CPU times: user 2min 51s, sys: 2.01 s, total: 2min 53s
# Wall time: 2min 9s

# %%
# %%time
for n_comp in range(30, 40):
    pca = PCA(n_components=n_comp)
    x_pca = pca.fit_transform(x)
    x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size = 0.25, random_state = 42)
    svm = SVC()
    svm.fit(x_train, y_train)
    comp_result = {"Components": n_comp, "Train_acc" : svm.score(x_train, y_train), "Test_acc" : svm.score(x_test, y_test)}
    results = results.append(comp_result, ignore_index=True)
# Out:
# CPU times: user 7min 53s, sys: 5.36 s, total: 7min 59s
# Wall time: 6min

# %%
# %%time
for n_comp in range(40, 60):
    pca = PCA(n_components=n_comp)
    x_pca = pca.fit_transform(x)
    x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size = 0.25, random_state = 42)
    svm = SVC()
    svm.fit(x_train, y_train)
    comp_result = {"Components": n_comp, "Train_acc" : svm.score(x_train, y_train), "Test_acc" : svm.score(x_test, y_test)}
    results = results.append(comp_result, ignore_index=True)
# Out:
# CPU times: user 18min 45s, sys: 34 s, total: 19min 19s
# Wall time: 14min 28s

# %%
# %%time
for n_comp in range(60, 80):
    pca = PCA(n_components=n_comp)
    x_pca = pca.fit_transform(x)
    x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size = 0.25, random_state = 42)
    svm = SVC()
    svm.fit(x_train, y_train)
    comp_result = {"Components": n_comp, "Train_acc" : svm.score(x_train, y_train), "Test_acc" : svm.score(x_test, y_test)}
    results = results.append(comp_result, ignore_index=True)
# Out:
# CPU times: user 25min, sys: 59.5 s, total: 25min 59s
# Wall time: 19min 39s

# %%
# %%time
for n_comp in range(80, 100):
    pca = PCA(n_components=n_comp)
    x_pca = pca.fit_transform(x)
    x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size = 0.25, random_state = 42)
    svm = SVC()
    svm.fit(x_train, y_train)
    comp_result = {"Components": n_comp, "Train_acc" : svm.score(x_train, y_train), "Test_acc" : svm.score(x_test, y_test)}
    results = results.append(comp_result, ignore_index=True)
# Out:
# CPU times: user 31min 43s, sys: 1min 12s, total: 32min 55s
# Wall time: 25min 27s

# %%
# %%time
for n_comp in range(100, 120):
    pca = PCA(n_components=n_comp)
    x_pca = pca.fit_transform(x)
    x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size = 0.25, random_state = 42)
    svm = SVC()
    svm.fit(x_train, y_train)
    comp_result = {"Components": n_comp, "Train_acc" : svm.score(x_train, y_train), "Test_acc" : svm.score(x_test, y_test)}
    results = results.append(comp_result, ignore_index=True)
# Out:
# CPU times: user 37min 49s, sys: 48.9 s, total: 38min 38s
# Wall time: 30min 27s

# %%
results.sort_values(by=['Test_acc'])
# Out:
#      Components  Train_acc  Test_acc
# 0           1.0   0.694551  0.694967
# 1           2.0   0.695257  0.694732
# 2           3.0   0.695335  0.694732
# 3           4.0   0.695335  0.694732
# 4           5.0   0.695414  0.694732
# 6           7.0   0.695414  0.694732
# 5           6.0   0.695492  0.694732
# 7           8.0   0.695492  0.694732
# 8           9.0   0.695806  0.694967
# 9          10.0   0.695806  0.695202
# 10         11.0   0.699726  0.695673
# 11         12.0   0.701058  0.696613
# 12         13.0   0.701215  0.696378
# 16         17.0   0.702626  0.698024
# 13         14.0   0.703018  0.697789
# 15         16.0   0.703646  0.697789
# 18         19.0   0.704508  0.698260
# 22         23.0   0.704508  0.698495
# 20         21.0   0.705057  0.698730
# 17         18.0   0.705214  0.697789
# 14         15.0   0.705762  0.701082
# 21         22.0   0.705841  0.700376
# 19         20.0   0.706076  0.699436
# 23         24.0   0.708742  0.701552
# 24         26.0   0.708742  0.701082
# 25         27.0   0.708898  0.701787
# 29         31.0   0.710702  0.702728
# 27         29.0   0.711172  0.703669
# 28         30.0   0.711407  0.703434
# 26         28.0   0.712270  0.703198
# 30         32.0   0.712505  0.703904
# 32         34.0   0.712897  0.703669
# 34         36.0   0.713524  0.703198
# 31         33.0   0.713681  0.704374
# 33         35.0   0.713759  0.705786
# 35         37.0   0.714308  0.706021
# 36         38.0   0.714622  0.704374
# 37         39.0   0.715484  0.707667
# 41         43.0   0.716190  0.705550
# 39         41.0   0.716974  0.705080
# 38         40.0   0.717679  0.709078
# 40         42.0   0.718385  0.707902
# 42         44.0   0.719326  0.710724
# 44         46.0   0.720815  0.713076
# 46         48.0   0.720815  0.712135
# 43         45.0   0.721443  0.710960
# 45         47.0   0.721521  0.710254
# 48         50.0   0.721991  0.710489
# 47         49.0   0.722305  0.712135
# 50         52.0   0.723089  0.710960
# 49         51.0   0.723638  0.714017
# 52         54.0   0.724971  0.715193
# 51         53.0   0.725441  0.711900
# 54         56.0   0.725598  0.714252
# 56         58.0   0.726225  0.711195
# 53         55.0   0.726303  0.712606
# 59         61.0   0.727009  0.712841
# 58         60.0   0.728263  0.712841
# 55         57.0   0.728577  0.713782
# 57         59.0   0.728655  0.715193
# 63         65.0   0.729439  0.714487
# 60         62.0   0.729988  0.716369
# 66         68.0   0.729988  0.715428
# 61         63.0   0.730223  0.714722
# 62         64.0   0.730537  0.712135
# 64         66.0   0.730537  0.716369
# 69         71.0   0.731164  0.716839
# 65         67.0   0.731791  0.717545
# 67         69.0   0.732027  0.717780
# 68         70.0   0.732183  0.713311
# 71         73.0   0.732262  0.714722
# 74         76.0   0.733046  0.718485
# 70         72.0   0.733516  0.718015
# 75         77.0   0.734222  0.717780
# 72         74.0   0.734379  0.717780
# 77         79.0   0.734614  0.720132
# 79         81.0   0.734614  0.718485
# 73         75.0   0.734614  0.716369
# 80         82.0   0.735084  0.717310
# 76         78.0   0.735319  0.719897
# 78         80.0   0.735398  0.718956
# 84         86.0   0.735711  0.718250
# 81         83.0   0.736652  0.718485
# 86         88.0   0.737044  0.718015
# 88         90.0   0.737044  0.717545
# 82         84.0   0.737593  0.718250
# 83         85.0   0.738220  0.720367
# 85         87.0   0.738220  0.719191
# 87         89.0   0.738769  0.720837
# 93         95.0   0.740102  0.719661
# 89         91.0   0.740337  0.720132
# 94         96.0   0.740416  0.719661
# 90         92.0   0.740494  0.719426
# 91         93.0   0.740886  0.719661
# 92         94.0   0.740886  0.722013
# 95         97.0   0.741200  0.721308
# 97         99.0   0.741670  0.721778
# 96         98.0   0.742140  0.720132
# 98        100.0   0.742140  0.718956
# 99        101.0   0.742376  0.721543
# 104       106.0   0.744257  0.721543
# 102       104.0   0.744336  0.722484
# 101       103.0   0.744649  0.718956
# 100       102.0   0.745355  0.720132
# 106       108.0   0.745433  0.722484
# 112       114.0   0.745904  0.722013
# 103       105.0   0.746139  0.720132
# 105       107.0   0.746452  0.721543
# 111       113.0   0.746531  0.718956
# 108       110.0   0.746923  0.722248
# 114       116.0   0.746923  0.721543
# 113       115.0   0.747001  0.720837
# 107       109.0   0.747315  0.723659
# 109       111.0   0.747315  0.720367
# 116       118.0   0.748099  0.722484
# 110       112.0   0.748099  0.721072
# 117       119.0   0.749902  0.724365
# 115       117.0   0.751470  0.723895

# %%
pca = PCA(n_components=115)
x_pca = pca.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size = 0.25, random_state = 42)

model = RandomForestClassifier(n_estimators=1000).fit(x_train, y_train)
pred_y = model.predict(x_test) 

print("R2-SCORE ", r2_score(y_test, pred_y)) 
print("ACCURACY ", accuracy_score(y_test, pred_y))
# Out:
# R2-SCORE  -0.09710439620605671
# ACCURACY  0.7648165569143932

# %%
x.columns[100:200]
# Out:
# Index(['KM', 'KN', 'KO', 'KR', 'KS', 'KU', 'KY', 'LA', 'LO', 'LT', 'LV', 'MG',
#        'MI', 'MK', 'ML', 'MN', 'MR', 'MS', 'MT', 'MY', 'NB', 'NE', 'NL', 'NN',
#        'NO', 'OM', 'OR', 'PA', 'PL', 'PS', 'PT', 'QU', 'RN', 'RO', 'RU', 'RW',
#        'SA', 'SD', 'SE', 'SI', 'SK', 'SL', 'SO', 'SQ', 'SR', 'SU', 'SV', 'SW',
#        'TA', 'TE', 'TG', 'TH', 'TI', 'TK', 'TL', 'TO', 'TR', 'TT', 'UG', 'UK',
#        'UR', 'UZ', 'VI', 'XH', 'YI', 'ZH', 'ZU', 'Book', 'Business',
#        'Education', 'Entertainment', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'Lifestyle', 'Medical', 'Music', 'Navigation',
#        'News', 'Productivity', 'Reference', 'Shopping', 'Social Networking',
#        'Sports', 'Stickers', 'Travel', 'Utilities', '"Alex Artem'ev"',
#        '"ByteRockers' Games GmbH & Co. KG"', '"Daniel O'Sullivan"',
#        '"Don't Blink Studios"', '"Ellie's Games, LLC"', '"Galen O'Shea"',
#        '"Igor's Software Labs LLC"', '"It's All A Game LLC"',
#        '"Joe o'donovan"', '"Joe's Apps"', '"Jordan Development's \u2122"',
#        '"King's Apps"', '"Let's Pick L.L.C."'],
#       dtype='object')

# %% [markdown]
# # Нейросеть

# %%
# %%time
from sklearn.neural_network import MLPClassifier
# Out:
# Wall time: 64.8 ms

# %%
# %%time

mlp_model = MLPClassifier(hidden_layer_sizes = (10,10),
        max_iter=300,
        activation = 'relu',
        solver='adam',
        random_state=1,
        alpha = 0.001)
mlp_model.fit(x_train, y_train)
# Out:
# Wall time: 9min 27s
# MLPClassifier(alpha=0.001, hidden_layer_sizes=(10, 10), max_iter=300,
#               random_state=1)

# %%
mlp_model.score(x_train, y_train)
# Out:
# 0.97734221873775

# %%
y_pred = mlp_model.predict(x_test)
y_pred2 = mlp_model.predict(x_train)

# %%
accuracy_score(y_train, y_pred2)
# Out:
# 0.97734221873775

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5094073377234243

# %%
neuron_number = [10, 50, 100, 200, 400, 500]
result_neuron_test = []
result_neuron_train = []
for i in neuron_number:
  mlp_model = MLPClassifier(hidden_layer_sizes = (i,i),
          max_iter=300,
          activation = 'relu',
          solver='adam',
          random_state=1,
          alpha = 0.001)
  mlp_model.fit(x_train, y_train)
  y_pred_test = mlp_model.predict(x_test)
  y_pred_train = mlp_model.predict(x_train)
  acc = accuracy_score(y_test_classes, y_pred_classes)
  message = message_template.format(
        neuron=i, r2Value=r2, accValue= acc
     )
  result_arr.append(message)
  print("R2-SCORE ", r2_score(y_test, y_pred)) 
  print("ACCURACY ", accuracy_score(y_test_classes, y_pred_classes))
# Out:
# C:\Users\cbkf1\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# R2-SCORE  -1.647275760595455
# ACCURACY  0.5268109125117592
# R2-SCORE  -0.305435657849023
# ACCURACY  0.672859830667921
# R2-SCORE  -0.27839067909898657
# ACCURACY  0.6789746001881467
# R2-SCORE  -0.44709242428736296
# ACCURACY  0.5733772342427094
# R2-SCORE  -0.24142200985152185
# ACCURACY  0.6822671683913453
# R2-SCORE  -0.3168900979058594
# ACCURACY  0.6328786453433678

# %%
print(result_arr)
# Out:
# ['neuron_number = 10, r2 =-1.647275760595455, acc = 0.5268109125117592', 'neuron_number = 50, r2 =-0.305435657849023, acc = 0.672859830667921', 'neuron_number = 100, r2 =-0.27839067909898657, acc = 0.6789746001881467', 'neuron_number = 200, r2 =-0.44709242428736296, acc = 0.5733772342427094', 'neuron_number = 400, r2 =-0.24142200985152185, acc = 0.6822671683913453', 'neuron_number = 500, r2 =-0.3168900979058594, acc = 0.6328786453433678']

# %%
alpha_values = [1,0.1, 0.01, 0.0001, 0.00001]
result_arr2 = []
message_template = "alpha_values = {alpha}, r2 ={r2Value}, acc = {accValue}"
for i in alpha_values:
  mlp_model = MLPClassifier(hidden_layer_sizes = (100,100),
          max_iter=300,
          activation = 'relu',
          solver='adam',
          random_state=1,
          alpha = i)
  mlp_model.fit(x_train, y_train)
  y_pred = mlp_model.predict(x_test)
  y_pred_classes = np.argmax(y_pred, axis=1)
  y_test_classes = np.argmax(y_test, axis=1)
  r2 = r2_score(y_test, y_pred)
  acc = accuracy_score(y_test_classes, y_pred_classes)
  message = message_template.format(
        alpha=i, r2Value=r2, accValue= acc
     )
  result_arr2.append(message)
  print("R2-SCORE ", r2_score(y_test, y_pred)) 
  print("ACCURACY ", accuracy_score(y_test_classes, y_pred_classes))
# Out:
# R2-SCORE  0.022512935687996033
# ACCURACY  0.7579962370649106
# R2-SCORE  -0.056903450853345805
# ACCURACY  0.7389463781749764
# R2-SCORE  -0.13245966840528522
# ACCURACY  0.7074317968015051
# R2-SCORE  -0.3437550068007519
# ACCURACY  0.6145343367826905
# R2-SCORE  -0.35436203662474586
# ACCURACY  0.6114769520225776

# %%
alpha_values = [1000,100, 10, 5, 4, 3, 2]
result_arr2 = []
message_template = "alpha_values = {alpha}, r2 ={r2Value}, acc = {accValue}"
for i in alpha_values:
  mlp_model = MLPClassifier(hidden_layer_sizes = (100,100),
          max_iter=300,
          activation = 'relu',
          solver='adam',
          random_state=1,
          alpha = i)
  mlp_model.fit(x_train, y_train)
  y_pred = mlp_model.predict(x_test)
  y_pred_classes = np.argmax(y_pred, axis=1)
  y_test_classes = np.argmax(y_test, axis=1)
  r2 = r2_score(y_test, y_pred)
  acc = accuracy_score(y_test_classes, y_pred_classes)
  message = message_template.format(
        alpha=i, r2Value=r2, accValue= acc
     )
  result_arr2.append(message)
  print("R2-SCORE ", r2_score(y_test, y_pred)) 
  print("ACCURACY ", accuracy_score(y_test_classes, y_pred_classes))
# Out:
# R2-SCORE  -0.19720300910838118
# ACCURACY  0.6944967074317968
# R2-SCORE  -0.19720300910838118
# ACCURACY  0.6944967074317968
# R2-SCORE  0.06534345146672602
# ACCURACY  0.7626999059266227
# R2-SCORE  0.05619412006594379
# ACCURACY  0.7594073377234243
# R2-SCORE  0.042746034189005466
# ACCURACY  0.7544684854186265
# R2-SCORE  0.03659994571343117
# ACCURACY  0.753527751646284
# R2-SCORE  0.04216653625720801
# ACCURACY  0.7563499529633114

# %%
print(result_arr2)
# Out:
# ['alpha_values = 1000, r2 =-0.19720300910838118, acc = 0.6944967074317968', 'alpha_values = 100, r2 =-0.19720300910838118, acc = 0.6944967074317968', 'alpha_values = 10, r2 =0.06534345146672602, acc = 0.7626999059266227', 'alpha_values = 5, r2 =0.05619412006594379, acc = 0.7594073377234243', 'alpha_values = 4, r2 =0.042746034189005466, acc = 0.7544684854186265', 'alpha_values = 3, r2 =0.03659994571343117, acc = 0.753527751646284', 'alpha_values = 2, r2 =0.04216653625720801, acc = 0.7563499529633114']

# %% [markdown]
# график зависимости точности от количества нейронов:

# %%
results = [0.52,0.67, 0.67, 0.57, 0.68, 0.63]

# %%
plt.plot(neuron_number, results)

# %% [markdown]
# график зависимости точности от aльфа: (количество нейронов - 100)

# %%
results2 = [0.69, 0.69, 0.76, 0.759, 0.754, 0.753, 0.756, 0.757, 0.738, 0.707, 0.614, 0.611]
alpha_values2 = [1000,100, 10, 5, 4, 3, 2, 1,0.1, 0.01, 0.0001, 0.00001]

# %%
plt.plot(alpha_values2, results2)

# %% [markdown]
# Количество нейронов - 100, alpha - 10, проверим еще раз

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %%
  mlp_model = MLPClassifier(hidden_layer_sizes = (100,100),
          max_iter=300,
          activation = 'relu',
          solver='adam',
          random_state=1,
          alpha = 10)
  mlp_model.fit(x_train, y_train)
  y_pred = mlp_model.predict(x_test)
  y_pred_classes = np.argmax(y_pred, axis=1)
  y_test_classes = np.argmax(y_test, axis=1)
  r2 = r2_score(y_test, y_pred)
  acc = accuracy_score(y_test_classes, y_pred_classes)
  print('acc = ', acc)
# Out:
# acc =  0.7626999059266227

# %% [markdown]
# Попробуем другой солвер (‘lbfgs’, ‘sgd’)

# %%
  mlp_model = MLPClassifier(hidden_layer_sizes = (100,100),
          max_iter=300,
          activation = 'relu',
          solver='sgd',
          random_state=1,
          alpha = 10)
  mlp_model.fit(x_train, y_train)
  y_pred = mlp_model.predict(x_test)
  y_pred_classes = np.argmax(y_pred, axis=1)
  y_test_classes = np.argmax(y_test, axis=1)
  r2 = r2_score(y_test, y_pred)
  acc = accuracy_score(y_test_classes, y_pred_classes)
  print('acc = ', acc)
# Out:
# C:\Users\cbkf1\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# acc =  0.7624647224835371

# %%
y_pred = mlp_model.predict(x_test)

# %%
neuron_number = [10, 50, 100, 200, 400, 500]
result_neuron_test = []
result_neuron_train = []
for i in neuron_number:
  mlp_model = MLPClassifier(hidden_layer_sizes = (i,i),
          max_iter=300,
          activation = 'relu',
          solver='adam',
          random_state=1,
          alpha = 0.001)
  mlp_model.fit(x_train, y_train)
  y_pred_test = mlp_model.predict(x_test)
  y_pred_train = mlp_model.predict(x_train)
  acc_test = accuracy_score(y_test, y_pred_test)
  acc_train = accuracy_score(y_train, y_pred_train)
  result_neuron_test.append(acc_test)
  result_neuron_train.append(acc_train)
  print("acc_test ", acc_test) 
  print("acc_train ", acc_train)
# Out:
# acc_test  0.5094073377234243
# acc_train  0.97734221873775
# acc_test  0.6554562558795861
# acc_train  0.991062328498628
# acc_test  0.6164158043273753
# acc_train  0.9735005880047041
# acc_test  0.7001411100658513
# acc_train  0.9877695021560172
# acc_test  0.6446378174976481
# acc_train  0.9846334770678166
# acc_test  0.658513640639699
# acc_train  0.9862014896119169

# %%
alpha_number = [0.0001,0.001,0.01,0.1,1,3,5,10, 50, 100, 200, 400, 500]
result_alpha_test = []
result_alpha_train = []
for i in alpha_number:
  mlp_model = MLPClassifier(hidden_layer_sizes = (100,100),
          max_iter=300,
          activation = 'relu',
          solver='adam',
          random_state=1,
          alpha = i)
  mlp_model.fit(x_train, y_train)
  y_pred_test = mlp_model.predict(x_test)
  y_pred_train = mlp_model.predict(x_train)
  acc_test = accuracy_score(y_test, y_pred_test)
  acc_train = accuracy_score(y_train, y_pred_train)
  result_alpha_train.append(acc_test)
  result_neuron_train.append(acc_train)
  print("acc_test ", acc_test) 
  print("acc_train ", acc_train)
# Out:
# acc_test  0.6359360301034808
# acc_train  0.9919247353978832
# acc_test  0.6164158043273753
# acc_train  0.9735005880047041
# acc_test  0.7119002822201317
# acc_train  0.9869854958839671
# acc_test  0.751175917215428
# acc_train  0.9837710701685614
# acc_test  0.7589369708372531
# acc_train  0.9669149353194826
# acc_test  0.7688146754468486
# acc_train  0.95515484123873
# acc_test  0.7622295390404515
# acc_train  0.9461387691101529
# acc_test  0.7622295390404515
# acc_train  0.937593100744806
# acc_test  0.6944967074317968
# acc_train  0.6940807526460212
# acc_test  0.6944967074317968
# acc_train  0.6940807526460212
# acc_test  0.6944967074317968
# acc_train  0.6940807526460212
# acc_test  0.6944967074317968
# acc_train  0.6940807526460212
# acc_test  0.6944967074317968
# acc_train  0.6940807526460212

# %%
result_neuron_train_clear = result_neuron_train[:6]

# %%
print(result_neuron_train_clear)
# Out:
# [0.97734221873775, 0.991062328498628, 0.9735005880047041, 0.9877695021560172, 0.9846334770678166, 0.9862014896119169]

# %%
result_alpha_train = result_neuron_train[6:]
print(result_alpha_train)
# Out:
# [0.9919247353978832, 0.9735005880047041, 0.9869854958839671, 0.9837710701685614, 0.9669149353194826, 0.95515484123873, 0.9461387691101529, 0.937593100744806, 0.6940807526460212, 0.6940807526460212, 0.6940807526460212, 0.6940807526460212, 0.6940807526460212]

# %%
result_alpha_test = [0.6359360301034808,
0.6164158043273753,
0.7119002822201317,
0.751175917215428,
0.7589369708372531,
0.7688146754468486,
0.7622295390404515,
0.7622295390404515,
0.6944967074317968,
0.6944967074317968,
0.6944967074317968,
0.6944967074317968,
0.6944967074317968]

# %%
plt.plot(neuron_number, result_neuron_train_clear, marker='*', label="train accuracy")
plt.plot(neuron_number, result_neuron_test, marker='*', label="test accuracy")
plt.title("Train and Test accuracy - Neurons number Two Layers")
plt.xlabel('count of neurons')
plt.ylabel("accuracy")
plt.xticks(neuron_number)
plt.legend()

# %%
plt.plot(alpha_number, result_alpha_train, marker='*', label="train accuracy")
plt.plot(alpha_number, result_alpha_test, marker='*', label="test accuracy")
plt.title("Train and Test accuracy - Alpha value  Two Layers")
plt.xlabel('Alpha value  ')
plt.ylabel("accuracy")
plt.xticks(alpha_number)
plt.legend()

# %% [markdown]
# Попробуем 1 слой

# %%
  mlp_model = MLPClassifier(hidden_layer_sizes = (100),
          max_iter=300,
          activation = 'relu',
          solver='adam',
          random_state=1,
          alpha = 3)
  mlp_model.fit(x_train, y_train)
  y_pred_test = mlp_model.predict(x_test)
  y_pred_train = mlp_model.predict(x_train)
  acc_test = accuracy_score(y_test, y_pred_test)
  acc_train = accuracy_score(y_train, y_pred_train)
  print("acc_test ", acc_test) 
  print("acc_train ", acc_train)
# Out:
# acc_test  0.764346190028222
# acc_train  0.9547628381027048

# %%
  mlp_model = MLPClassifier(hidden_layer_sizes = (100),
          max_iter=300,
          activation = 'relu',
          solver='sgd',
          random_state=1,
          alpha = 3)
  mlp_model.fit(x_train, y_train)
  y_pred_test = mlp_model.predict(x_test)
  y_pred_train = mlp_model.predict(x_train)
  acc_test = accuracy_score(y_test, y_pred_test)
  acc_train = accuracy_score(y_train, y_pred_train)
  print("acc_test ", acc_test) 
  print("acc_train ", acc_train)
# Out:
# C:\Users\cbkf1\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# acc_test  0.7650517403574788
# acc_train  0.9589180713445707

# %%
  mlp_model = MLPClassifier(hidden_layer_sizes = (100),
          max_iter=300,
          activation = 'relu',
          solver='lbfgs',
          random_state=1,
          alpha = 3)
  mlp_model.fit(x_train, y_train)
  y_pred_test = mlp_model.predict(x_test)
  y_pred_train = mlp_model.predict(x_train)
  acc_test = accuracy_score(y_test, y_pred_test)
  acc_train = accuracy_score(y_train, y_pred_train)
  print("acc_test ", acc_test) 
  print("acc_train ", acc_train)
# Out:
# C:\Users\cbkf1\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# acc_test  0.7617591721542804
# acc_train  0.9950607604860839

# %%
  mlp_model = MLPClassifier(hidden_layer_sizes = (100),
          max_iter=500,
          activation = 'relu',
          solver='sgd',
          random_state=1,
          alpha = 3)
  mlp_model.fit(x_train, y_train)
  y_pred_test = mlp_model.predict(x_test)
  y_pred_train = mlp_model.predict(x_train)
  acc_test = accuracy_score(y_test, y_pred_test)
  acc_train = accuracy_score(y_train, y_pred_train)
  print("acc_test ", acc_test) 
  print("acc_train ", acc_train)
# Out:
# acc_test  0.7645813734713076
# acc_train  0.9598588788710309

# %% [markdown]
# кросс-валидация

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(mlp_model, x, y, cv=5)
print("кросс-валидация: ", scores)
# Out:
# кросс-валидация:  [0.7345679  0.74603175 0.73743017 0.7330197  0.71478977]

# %% [markdown]
# # Выводы
# имея ввиду то, что возрастное ограничение '4+' составляет 69% из всех игр, а мы имеем точность всего 71%
# можно сказать, что возрастное ограничение игры, основываясь на ее жанрах, разработчике, размере, дате релиза и т.д. угадать очень сложно(по крайней мере используя метод ближайших соседей)
#
# Лучшая точность для KNN это 72.9% при 5 соседей.

# %% [markdown]
# Лучший результат для PCA и SVC - 72,4%, переобучение сравнимо с KNN

# %% [markdown]
# Самый хороший результат я получил при методе RF и PCA: точность 0.76, 115 компонет (без PCA примерно столько же)

# %% [markdown]
# Таким образом На проверяемых мной количествах компонент PCA не помог на моих данных. Я связываю это с тем, что данные в датасете оказались слабо коррелируемыми и понижение размерности не сильно помогает в этом случае.

# %% [markdown]
# Однако заметим, что мы так и не вышли на плато по PCA, возможно с увеличение количества компонент у нас будет увеличиваться точность. Это пока не было проверено из-за долгости подсчета функций

# %%
Самый хороший результат я получил при методе RF и PCA: точность 0.76, 115 компонет (без PCA примерно столько же)

# %% [markdown]
# ### Вывод нейросети

# %% [markdown]
# Один и два слоя не повлияли на резлуьтат
# лучший результат при одном слое, количество нейронов 100
# альфа - 300
# функция активации - релу
# acc_test  0.7645813734713076
# acc_train  0.9598588788710309
# Однако, получаем слишком большое переобучение
#
# При большем значении альфа имеем равное значение точности на обучающей и тестововой выборке, но оно сопоставимо с размером одного из классов
